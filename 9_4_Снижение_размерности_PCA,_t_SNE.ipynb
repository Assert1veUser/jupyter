# %% [markdown]
# # Методы снижения размерности
#
# Довольно часто бывает так, что признаков очень много. Хочется уменьшить их число, чтобы задача по-прежнему хорошо решалась. В этом случае нам нужно будет оценивать меньше параметров в модели, и она станет более интерпретируемой: сравните линейную регрессию с двумя признаками и с пятьюстами. В каком случае понятнее, почему модель приняла то или иное решение?
#
# В этой тетради мы посмотрим на несколько различных способов снизить  размерность данных.

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # 1. Отбор признаков
#
# Самый простой способ выделения признаков &mdash; их отбор. Есть много разных стратегий отбора признаков:
#
#
# - __Одномерные стратегии:__ считаем, насколько сильно признаки связаны с таргетом с помощью разных метрик, оставляем только самые связанные
# - __Жадные методы отбора признаков:__ надстройки над методами обучения моделей. Они перебирают различные подмножества признаков и выбирают то из них, которое дает наилучшее качество определенной модели машинного обучения. Данный процесс устроен следующим образом. Обучение модели считается черным ящиком, который на вход принимает информацию о том, какие из его признаков можно использовать при обучении модели, обучает модель, и дальше каким-то методом оценивается качество такой модели, например по отложенной выборке или кросс-валидации. Таким образом, задача, которую необходимо решить, — это оптимизация функционала качества модели по подмножеству признаков. Признаки обычно перебираются по какому-то алгоритму. Например, можно попробовать все комбинации (очень долго и неэффективно)
# - __Отбор признаков на основе моделей__
#
# Отберем признаки на основе их корреляции с целевым признаком и сравним результаты с исходными.

# %%
from sklearn.linear_model import LinearRegression
from scipy.stats import pearsonr

from sklearn.datasets import fetch_california_housing

# %% [markdown]
# Начнем с подсчета корреляции между входными и целевыми признаками для наших данных. Чем больше абсолютное значение корреляции Пирсона (чем больше линейная связь между ними), тем выше важность признака по этому критерию.

# %%
# Загрузка данных
ds = fetch_california_housing()

# Получим значения входных и выходных переменных
X, y = ds.data, ds.target
indexes = np.arange(len(y))
np.random.seed(52342)
np.random.shuffle(indexes)
X = X[indexes, :]
y = y[indexes]

# Посчитаем корреляции признаков с целевой переменной
features_ind = np.arange(X.shape[1])
corrs = np.abs([pearsonr(X[:, i], y)[0] for i in features_ind])
importances_sort = np.argsort(corrs)

# Нарисуем полученные корреляции
fig = plt.figure(figsize=(16, 8))
plt.barh(features_ind, corrs[importances_sort])
plt.xlabel('Feature importance', fontsize=20)
plt.ylabel('Feature index', fontsize=20)
X = X[:, importances_sort]

# %%
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor

# %% [markdown]
# Теперь давайте построим модели, в которых будет разное количество входных признаков, имеющих наибольшие абсолютные значения корреляции.

# %%
features_counts = np.arange(X.shape[1])

def scores_by_features_count(reg):
    scores = []
    for features_part in features_counts:
        X_part = X[:, importances_sort[features_part:]]
        scores.append(cross_val_score(reg, X_part, y).mean())
    return scores

linreg_scores = scores_by_features_count(LinearRegression())
rf_scores = scores_by_features_count(RandomForestRegressor(n_estimators=100, max_depth=3))

# %%
plt.figure(figsize=(16,8))

plt.plot(features_counts, linreg_scores, label='LinearRegression')
plt.plot(features_counts, rf_scores, label='RandomForest')
plt.legend(loc='best', fontsize=20)
plt.xlabel('Number of deleted features', fontsize=20)
plt.ylabel('$R^2$ metric', fontsize=20)
plt.grid()

# %% [markdown]
# Если мы захотим немного сократить потребление ресурсов, пожертвовав частью качества,
# видно, что это можно сделать.
#
# Для себя можете попробовать ответить на два вопроса, подумав или написав соответствующий код:
# 1. Означают ли полученные результаты, что отбор признаков по корреляции лучше случайного выбора множества признаков того же размера? Какой эксперимент поможет нам понять, так это или нет?
# 2. Что в подобной процедуре отбора признаков может привести к переобучению? Как этого можно было бы избежать?

# %% [markdown]
# # 2. Метод главных компонент (Principal Component Analysis, PCA)
#
# Выделение новых признаков путем их отбора часто дает плохие результаты, и в некоторых ситуациях такой подход практически бесполезен. Например, если мы работаем с изображениями, у которых признаками являются яркости пикселей,
# невозможно выбрать небольшой поднабор пикселей, который дает хорошую информацию о содержимом картинки. Поэтому признаки нужно как-то комбинировать.
#
# __Метод главных компонент__ &mdash; один из самых интуитивно простых и часто используемых методов для снижения размерности данных и проекции их на ортогональное подпространство признаков. В рамках метода делается два важных упрощения задачи:
#
# 1. Игнорируется целевая переменная, мы смотрим только на пространство входных признаков
# 2. Строится линейное преобразование исходных признаков, сохраняющее большую часть доступной информации
#
# П. 1 на первый взгляд кажется довольно странным, но на практике обычно не является таким уж плохим. Это связано с тем, что часто у данных есть внутренняя структура в пространстве меньшей размерности, которая никак не связана с целевой переменной. Поэтому и оптимальные признаки можно строить, не глядя на ответ.
#
# П. 2 тоже сильно упрощает задачу, но далее мы рассмотрим и более сложные нелинейные методы.

# %% [markdown]
# ### Теория
#
# Вспомним, что делает этот метод.
#
# Пусть $X$ &mdash; матрица объекты-признаки с нулевым средним каждого признака, а $w$ &mdash; некоторый единичный вектор. Тогда $Xw$ задает величину проекций всех объектов на этот вектор. Далее ищется вектор, который дает наибольшую дисперсию полученных проекций (то есть наибольшую дисперсию вдоль этого направления). Формально получаем следующую оптимизационную задачу:
#
# $$
# \max_{w: \|w\|=1} \| Xw \|^2 =  \max_{w: \|w\|=1} w^T X^T X w
# $$
#
# Подходящий вектор тогда равен собственному вектору матрицы $X^T X$ с наибольшим собственным значением. После этого все пространство проецируется на ортогональное дополнение к вектору $w$, и процесс повторяется.

# %% [markdown]
# ## 2.1. PCA на плоскости
#
# Для начала посмотрим на метод PCA на плоскости, для того чтобы лучше понять, как он устроен. Попробуем специально сделать один из признаков более значимым и проверим, что PCA это обнаружит. Сгенерируем выборку из двухмерного нормального распределения с нулевым математическим ожиданием.

# %%
np.random.seed(314512)

data_synth_1 = np.random.multivariate_normal(
    mean=[0, 0], 
    cov=[[4, 0], 
         [0, 1]],
    size=1000
)

# %% [markdown]
# Теперь изобразим точки выборки на плоскости и применим к ним PCA для нахождения главных компонент. В результате работы PCA из sklearn в `dec.components_` будут лежать главные направления (нормированные), а в `dec.explained_variance_` &mdash; дисперсия, которую объясняет каждая компонента. Изобразим на нашем графике эти направления, умножив их на дисперсию для наглядного отображения их значимости.

# %%
from sklearn.decomposition import PCA

def PCA_show(dataset):
    plt.scatter(*zip(*dataset), alpha=0.5)
    
    dec = PCA()
    dec.fit(dataset)
    ax = plt.gca()
    for comp_ind in range(dec.components_.shape[0]):
        component = dec.components_[comp_ind, :]
        var = dec.explained_variance_[comp_ind]
        start, end = dec.mean_, component * var
        ax.arrow(start[0], start[1], end[0], end[1],
                 head_width=0.2, head_length=0.4, fc='r', ec='r')
    
    ax.set_aspect('equal', adjustable='box')

plt.figure(figsize=(16, 8))
PCA_show(data_synth_1)

# %% [markdown]
# Видим, что PCA правильно выделил главные компоненты. Но это, конечно, можно было сделать и просто посчитав
# дисперсию каждого признака. Повернем наши данные на некоторый фиксированный угол и проверим,
# что для PCA это ничего не изменит.

# %%
angle = np.pi / 6
rotate = np.array([
        [np.cos(angle), - np.sin(angle)],
        [np.sin(angle), np.cos(angle)],
    ])
data_synth_2 = rotate.dot(data_synth_1.T).T

plt.figure(figsize=(16, 8))
PCA_show(data_synth_2)

# %% [markdown]
# Ниже — пара примеров, где PCA отработал не так хорошо, и полученные им направления задают не очень хорошие признаки.
#
# **Упражнение:** объясните, почему так произошло.

# %%
from sklearn.datasets import make_circles, make_moons, make_blobs

np.random.seed(54242)

data_synth_bad = [
    make_circles(n_samples=1000, factor=0.2, noise=0.1)[0]*2,
    make_moons(n_samples=1000, noise=0.1)[0]*2,
    make_blobs(n_samples=1000, n_features=2, centers=4)[0]/5,
    np.random.multivariate_normal(
        mean=[0, 1.5], 
        cov=[[3, 1], 
             [1, 1]],
        size=1000),
]

plt.figure(figsize=(16,8))
rows, cols = 2, 2
for i, data in enumerate(data_synth_bad):
    plt.subplot(rows, cols, i + 1)
    PCA_show(data)

# %% [markdown]
# ## 2.2. Лица людей
#
# Рассмотрим датасет с фотографиями лиц людей и применим его к признакам PCA. Ниже изображены примеры лиц из базы, и последняя картинка &mdash; это «среднее лицо».

# %%
from sklearn.datasets import fetch_olivetti_faces

faces = fetch_olivetti_faces(shuffle=True, random_state=432542)
faces_images = faces.data
faces_ids = faces.target
image_shape = (64, 64)
    
mean_face = faces_images.mean(axis=0)

plt.figure(figsize=(16, 8))
rows, cols = 2, 4
n_samples = rows * cols
for i in range(n_samples - 1):
    plt.subplot(rows, cols, i + 1)
    plt.imshow(faces_images[i, :].reshape(image_shape), interpolation='none',
               cmap='gray')
    plt.xticks(())
    plt.yticks(())
    
plt.subplot(rows, cols, n_samples)
plt.imshow(mean_face.reshape(image_shape), interpolation='none',
           cmap='gray')
plt.xticks(())
_ = plt.yticks(())

# %% [markdown]
# Теперь найдем главные компоненты.

# %%
model_pca = PCA()
faces_images -= mean_face  # отнормировали данные к нулевому среднему
model_pca.fit(faces_images)

plt.figure(figsize=(16, 8))
rows, cols = 2, 4
n_samples = rows * cols
for i in range(n_samples):
    plt.subplot(rows, cols, i + 1)
    plt.imshow(model_pca.components_[i, :].reshape(image_shape), interpolation='none', cmap='gray')
    plt.xticks(())
    plt.yticks(())

# %% [markdown]
# Получилось жутковато, что уже неплохо, но есть ли от этого какая-то польза?
#
# - Во-первых, новые признаки дают более высокое качество классификации

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV

gscv_rf = GridSearchCV(
    RandomForestClassifier(),
    {'n_estimators': [100, 200, 500, 800], 'max_depth': [2, 3, 4, 5]}, cv=5
)

# %%
# %%time
gscv_rf.fit(faces_images, faces_ids)
print(gscv_rf.best_score_)
# Out:
# 0.825
# CPU times: total: 4min 9s
# Wall time: 4min 9s

# %%
# %%time
gscv_rf.fit(model_pca.transform(faces_images)[:,:100], faces_ids)
print(gscv_rf.best_score_)
# Out:
# 0.9125
# CPU times: total: 1min 30s
# Wall time: 1min 29s

# %% [markdown]
# На практике обычно выбирают столько главных компонент, чтобы оставить 90 % дисперсии исходных данных. В данном случае для этого достаточно выделить около 60 главных компонент, то есть можно снизить размерность с 4 096 признаков до 60, потеряв только 10 % информации!

# %%
faces_images.shape
# Out:
# (400, 4096)

# %%
plt.figure(figsize=(10, 7))
plt.plot(np.cumsum(model_pca.explained_variance_ratio_), color='k', lw=2)
plt.xlabel('Number of components')
plt.ylabel('Total explained variance')
plt.xlim(0, 63)
plt.yticks(np.arange(0, 1.1, 0.1))
plt.axvline(21, c='b')
plt.axhline(0.9, c='r')
plt.show();

# %% [markdown]
#  - Во-вторых, их можно использовать для компактного хранения данных. Для этого объекты трансформируются в новое пространство, и из него выкидываются самые незначимые признаки. Ниже приведены результаты сжатия в 20 раз

# %%
base_size = image_shape[0] * image_shape[1]

def compress_and_show(compress_ratio):
    model_pca = PCA(n_components=int(base_size * compress_ratio))
    model_pca.fit(faces_images)

    faces_compressed = model_pca.transform(faces_images)
    
    # обратное преобразование
    faces_restored = model_pca.inverse_transform(faces_compressed) + mean_face

    plt.figure(figsize=(16, 8))
    rows, cols = 2, 4
    n_samples = rows * cols
    for i in range(n_samples):
        plt.subplot(rows, cols, i + 1)
        plt.imshow(faces_restored[i, :].reshape(image_shape), interpolation='none',
                   cmap='gray')
        plt.xticks(())
        plt.yticks(())
        
compress_and_show(0.05)

# %% [markdown]
# Даже при сжатии в 50 раз лица остаются узнаваемыми.

# %%
compress_and_show(0.02)

# %% [markdown]
# ## 2.3. PCA для визуализации химического состава рек

# %% [markdown]
# Посмотрим на еще один пример применения метода главных компонент. Будем работать с подмножеством [датасета о химическом составе воды](http://data.europa.eu/euodp/en/data/dataset/data_waterbase-rivers-10) в разных реках.

# %%
# !pip install vaex
# Out:
# Collecting vaex
#   Downloading vaex-4.17.0-py3-none-any.whl.metadata (6.0 kB)
# Collecting vaex-core~=4.17.1 (from vaex)
#   Downloading vaex-core-4.17.1.tar.gz (2.5 MB)
#      ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#      ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#      ---------------------------------------- 0.0/2.5 MB 330.3 kB/s eta 0:00:08
#       --------------------------------------- 0.0/2.5 MB 326.8 kB/s eta 0:00:08
#      - -------------------------------------- 0.1/2.5 MB 653.6 kB/s eta 0:00:04
#      ---- ----------------------------------- 0.3/2.5 MB 1.4 MB/s eta 0:00:02
#      ------ --------------------------------- 0.4/2.5 MB 1.8 MB/s eta 0:00:02
#      ------------- -------------------------- 0.8/2.5 MB 2.9 MB/s eta 0:00:01
#      -------------- ------------------------- 0.9/2.5 MB 3.0 MB/s eta 0:00:01
#      -------------- ------------------------- 0.9/2.5 MB 2.6 MB/s eta 0:00:01
#      -------------------- ------------------- 1.3/2.5 MB 3.0 MB/s eta 0:00:01
#      ---------------------------------------  2.5/2.5 MB 5.2 MB/s eta 0:00:01
#      ---------------------------------------- 2.5/2.5 MB 4.9 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting vaex-astro<0.10,>=0.9.3 (from vaex)
#   Downloading vaex_astro-0.9.3-py3-none-any.whl.metadata (345 bytes)
# Collecting vaex-hdf5<0.15,>=0.13.0 (from vaex)
#   Downloading vaex_hdf5-0.14.1-py3-none-any.whl.metadata (321 bytes)
# Collecting vaex-viz<0.6,>=0.5.4 (from vaex)
#   Downloading vaex_viz-0.5.4-py3-none-any.whl.metadata (345 bytes)
# Collecting vaex-server~=0.9.0 (from vaex)
#   Downloading vaex_server-0.9.0-py3-none-any.whl.metadata (430 bytes)
# Collecting vaex-jupyter<0.9,>=0.8.2 (from vaex)
#   Downloading vaex_jupyter-0.8.2-py3-none-any.whl.metadata (517 bytes)
# Collecting vaex-ml<0.19,>=0.18.3 (from vaex)
#   Downloading vaex_ml-0.18.3-py3-none-any.whl.metadata (485 bytes)
# Requirement already satisfied: astropy in d:\anaconda3\lib\site-packages (from vaex-astro<0.10,>=0.9.3->vaex) (5.3.4)
# Requirement already satisfied: numpy>=1.16 in d:\anaconda3\lib\site-packages (from vaex-core~=4.17.1->vaex) (1.26.4)
# Collecting aplus (from vaex-core~=4.17.1->vaex)
#   Downloading aplus-0.11.0.tar.gz (3.7 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: tabulate>=0.8.3 in d:\anaconda3\lib\site-packages (from vaex-core~=4.17.1->vaex) (0.9.0)
# Requirement already satisfied: future>=0.15.2 in d:\anaconda3\lib\site-packages (from vaex-core~=4.17.1->vaex) (0.18.3)
# Requirement already satisfied: pyyaml in d:\anaconda3\lib\site-packages (from vaex-core~=4.17.1->vaex) (6.0.1)
# Collecting progressbar2 (from vaex-core~=4.17.1->vaex)
#   Downloading progressbar2-4.4.2-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: requests in d:\anaconda3\lib\site-packages (from vaex-core~=4.17.1->vaex) (2.31.0)
# Requirement already satisfied: six in d:\anaconda3\lib\site-packages (from vaex-core~=4.17.1->vaex) (1.16.0)
# Requirement already satisfied: cloudpickle in d:\anaconda3\lib\site-packages (from vaex-core~=4.17.1->vaex) (2.2.1)
# Requirement already satisfied: pandas in d:\anaconda3\lib\site-packages (from vaex-core~=4.17.1->vaex) (2.1.4)
# Requirement already satisfied: dask!=2022.4.0 in d:\anaconda3\lib\site-packages (from vaex-core~=4.17.1->vaex) (2023.11.0)
# Requirement already satisfied: nest-asyncio>=1.3.3 in d:\anaconda3\lib\site-packages (from vaex-core~=4.17.1->vaex) (1.6.0)
# Requirement already satisfied: pyarrow>=5.0.0 in d:\anaconda3\lib\site-packages (from vaex-core~=4.17.1->vaex) (14.0.2)
# Collecting frozendict!=2.2.0 (from vaex-core~=4.17.1->vaex)
#   Downloading frozendict-2.4.2.tar.gz (315 kB)
#      ---------------------------------------- 0.0/315.3 kB ? eta -:--:--
#      ---------------------- -------------- 194.6/315.3 kB 12.3 MB/s eta 0:00:01
#      ------------------------ ------------- 204.8/315.3 kB 2.5 MB/s eta 0:00:01
#      ------------------------ ------------- 204.8/315.3 kB 2.5 MB/s eta 0:00:01
#      ----------------------------- -------- 245.8/315.3 kB 1.5 MB/s eta 0:00:01
#      -------------------------------------  307.2/315.3 kB 1.3 MB/s eta 0:00:01
#      -------------------------------------- 315.3/315.3 kB 1.2 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting blake3 (from vaex-core~=4.17.1->vaex)
#   Downloading blake3-0.4.1-cp311-none-win_amd64.whl.metadata (4.2 kB)
# Requirement already satisfied: filelock in d:\anaconda3\lib\site-packages (from vaex-core~=4.17.1->vaex) (3.13.1)
# Requirement already satisfied: pydantic>=1.8.0 in d:\anaconda3\lib\site-packages (from vaex-core~=4.17.1->vaex) (1.10.12)
# Requirement already satisfied: rich in d:\anaconda3\lib\site-packages (from vaex-core~=4.17.1->vaex) (13.3.5)
# Requirement already satisfied: h5py>=2.9 in d:\anaconda3\lib\site-packages (from vaex-hdf5<0.15,>=0.13.0->vaex) (3.9.0)
# Collecting bqplot>=0.10.1 (from vaex-jupyter<0.9,>=0.8.2->vaex)
#   Downloading bqplot-0.12.43-py2.py3-none-any.whl.metadata (6.4 kB)
# Collecting ipyvolume>=0.4 (from vaex-jupyter<0.9,>=0.8.2->vaex)
#   Downloading ipyvolume-0.6.3-py3-none-any.whl.metadata (2.3 kB)
# Collecting ipyleaflet (from vaex-jupyter<0.9,>=0.8.2->vaex)
#   Downloading ipyleaflet-0.19.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting ipympl (from vaex-jupyter<0.9,>=0.8.2->vaex)
#   Downloading ipympl-0.9.4-py3-none-any.whl.metadata (8.7 kB)
# Collecting ipyvuetify<2,>=1.2.2 (from vaex-jupyter<0.9,>=0.8.2->vaex)
#   Downloading ipyvuetify-1.9.4-py2.py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: xarray in d:\anaconda3\lib\site-packages (from vaex-jupyter<0.9,>=0.8.2->vaex) (2023.6.0)
# Requirement already satisfied: numba in d:\anaconda3\lib\site-packages (from vaex-ml<0.19,>=0.18.3->vaex) (0.59.0)
# Requirement already satisfied: traitlets in d:\anaconda3\lib\site-packages (from vaex-ml<0.19,>=0.18.3->vaex) (5.7.1)
# Requirement already satisfied: jinja2 in d:\anaconda3\lib\site-packages (from vaex-ml<0.19,>=0.18.3->vaex) (3.1.3)
# Requirement already satisfied: tornado>4.1 in d:\anaconda3\lib\site-packages (from vaex-server~=0.9.0->vaex) (6.3.3)
# Requirement already satisfied: cachetools in d:\anaconda3\lib\site-packages (from vaex-server~=0.9.0->vaex) (4.2.2)
# Collecting fastapi (from vaex-server~=0.9.0->vaex)
#   Downloading fastapi-0.110.2-py3-none-any.whl.metadata (24 kB)
# Collecting uvicorn[standard] (from vaex-server~=0.9.0->vaex)
#   Downloading uvicorn-0.29.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: matplotlib>=1.3.1 in d:\anaconda3\lib\site-packages (from vaex-viz<0.6,>=0.5.4->vaex) (3.8.0)
# Requirement already satisfied: pillow in d:\anaconda3\lib\site-packages (from vaex-viz<0.6,>=0.5.4->vaex) (10.2.0)
# Requirement already satisfied: ipywidgets<9,>=7.5.0 in d:\anaconda3\lib\site-packages (from bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (7.6.5)
# Collecting traittypes>=0.0.6 (from bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex)
#   Downloading traittypes-0.2.1-py2.py3-none-any.whl.metadata (1.0 kB)
# Requirement already satisfied: click>=8.1 in d:\anaconda3\lib\site-packages (from dask!=2022.4.0->vaex-core~=4.17.1->vaex) (8.1.7)
# Requirement already satisfied: fsspec>=2021.09.0 in d:\anaconda3\lib\site-packages (from dask!=2022.4.0->vaex-core~=4.17.1->vaex) (2023.10.0)
# Requirement already satisfied: packaging>=20.0 in d:\anaconda3\lib\site-packages (from dask!=2022.4.0->vaex-core~=4.17.1->vaex) (23.1)
# Requirement already satisfied: partd>=1.2.0 in d:\anaconda3\lib\site-packages (from dask!=2022.4.0->vaex-core~=4.17.1->vaex) (1.4.1)
# Requirement already satisfied: toolz>=0.10.0 in d:\anaconda3\lib\site-packages (from dask!=2022.4.0->vaex-core~=4.17.1->vaex) (0.12.0)
# Requirement already satisfied: importlib-metadata>=4.13.0 in d:\anaconda3\lib\site-packages (from dask!=2022.4.0->vaex-core~=4.17.1->vaex) (7.0.1)
# Collecting ipywebrtc (from ipyvolume>=0.4->vaex-jupyter<0.9,>=0.8.2->vaex)
#   Downloading ipywebrtc-0.6.0-py2.py3-none-any.whl.metadata (825 bytes)
# Collecting ipyvue>=1.7.0 (from ipyvolume>=0.4->vaex-jupyter<0.9,>=0.8.2->vaex)
#   Downloading ipyvue-1.11.0-py2.py3-none-any.whl.metadata (1.1 kB)
# Collecting pythreejs>=2.4.0 (from ipyvolume>=0.4->vaex-jupyter<0.9,>=0.8.2->vaex)
#   Downloading pythreejs-2.4.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: contourpy>=1.0.1 in d:\anaconda3\lib\site-packages (from matplotlib>=1.3.1->vaex-viz<0.6,>=0.5.4->vaex) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in d:\anaconda3\lib\site-packages (from matplotlib>=1.3.1->vaex-viz<0.6,>=0.5.4->vaex) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in d:\anaconda3\lib\site-packages (from matplotlib>=1.3.1->vaex-viz<0.6,>=0.5.4->vaex) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\anaconda3\lib\site-packages (from matplotlib>=1.3.1->vaex-viz<0.6,>=0.5.4->vaex) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\anaconda3\lib\site-packages (from matplotlib>=1.3.1->vaex-viz<0.6,>=0.5.4->vaex) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in d:\anaconda3\lib\site-packages (from matplotlib>=1.3.1->vaex-viz<0.6,>=0.5.4->vaex) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in d:\anaconda3\lib\site-packages (from pandas->vaex-core~=4.17.1->vaex) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in d:\anaconda3\lib\site-packages (from pandas->vaex-core~=4.17.1->vaex) (2023.3)
# Requirement already satisfied: typing-extensions>=4.2.0 in d:\anaconda3\lib\site-packages (from pydantic>=1.8.0->vaex-core~=4.17.1->vaex) (4.9.0)
# Requirement already satisfied: pyerfa>=2.0 in d:\anaconda3\lib\site-packages (from astropy->vaex-astro<0.10,>=0.9.3->vaex) (2.0.0)
# Collecting starlette<0.38.0,>=0.37.2 (from fastapi->vaex-server~=0.9.0->vaex)
#   Downloading starlette-0.37.2-py3-none-any.whl.metadata (5.9 kB)
# Collecting branca>=0.5.0 (from ipyleaflet->vaex-jupyter<0.9,>=0.8.2->vaex)
#   Downloading branca-0.7.1-py3-none-any.whl.metadata (1.5 kB)
# Collecting jupyter-leaflet<0.20,>=0.19 (from ipyleaflet->vaex-jupyter<0.9,>=0.8.2->vaex)
#   Downloading jupyter_leaflet-0.19.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: xyzservices>=2021.8.1 in d:\anaconda3\lib\site-packages (from ipyleaflet->vaex-jupyter<0.9,>=0.8.2->vaex) (2022.9.0)
# Requirement already satisfied: ipython-genutils in d:\anaconda3\lib\site-packages (from ipympl->vaex-jupyter<0.9,>=0.8.2->vaex) (0.2.0)
# Requirement already satisfied: ipython<9 in d:\anaconda3\lib\site-packages (from ipympl->vaex-jupyter<0.9,>=0.8.2->vaex) (8.20.0)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\anaconda3\lib\site-packages (from jinja2->vaex-ml<0.19,>=0.18.3->vaex) (2.1.3)
# Requirement already satisfied: llvmlite<0.43,>=0.42.0dev0 in d:\anaconda3\lib\site-packages (from numba->vaex-ml<0.19,>=0.18.3->vaex) (0.42.0)
# Collecting python-utils>=3.8.1 (from progressbar2->vaex-core~=4.17.1->vaex)
#   Downloading python_utils-3.8.2-py2.py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\anaconda3\lib\site-packages (from requests->vaex-core~=4.17.1->vaex) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\anaconda3\lib\site-packages (from requests->vaex-core~=4.17.1->vaex) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\anaconda3\lib\site-packages (from requests->vaex-core~=4.17.1->vaex) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda3\lib\site-packages (from requests->vaex-core~=4.17.1->vaex) (2024.2.2)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in d:\anaconda3\lib\site-packages (from rich->vaex-core~=4.17.1->vaex) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in d:\anaconda3\lib\site-packages (from rich->vaex-core~=4.17.1->vaex) (2.15.1)
# Collecting h11>=0.8 (from uvicorn[standard]->vaex-server~=0.9.0->vaex)
#   Using cached h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: colorama>=0.4 in d:\anaconda3\lib\site-packages (from uvicorn[standard]->vaex-server~=0.9.0->vaex) (0.4.6)
# Collecting httptools>=0.5.0 (from uvicorn[standard]->vaex-server~=0.9.0->vaex)
#   Downloading httptools-0.6.1-cp311-cp311-win_amd64.whl.metadata (3.7 kB)
# Requirement already satisfied: python-dotenv>=0.13 in d:\anaconda3\lib\site-packages (from uvicorn[standard]->vaex-server~=0.9.0->vaex) (0.21.0)
# Collecting watchfiles>=0.13 (from uvicorn[standard]->vaex-server~=0.9.0->vaex)
#   Downloading watchfiles-0.21.0-cp311-none-win_amd64.whl.metadata (5.0 kB)
# Requirement already satisfied: websockets>=10.4 in d:\anaconda3\lib\site-packages (from uvicorn[standard]->vaex-server~=0.9.0->vaex) (10.4)
# Requirement already satisfied: zipp>=0.5 in d:\anaconda3\lib\site-packages (from importlib-metadata>=4.13.0->dask!=2022.4.0->vaex-core~=4.17.1->vaex) (3.17.0)
# Requirement already satisfied: decorator in d:\anaconda3\lib\site-packages (from ipython<9->ipympl->vaex-jupyter<0.9,>=0.8.2->vaex) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in d:\anaconda3\lib\site-packages (from ipython<9->ipympl->vaex-jupyter<0.9,>=0.8.2->vaex) (0.18.1)
# Requirement already satisfied: matplotlib-inline in d:\anaconda3\lib\site-packages (from ipython<9->ipympl->vaex-jupyter<0.9,>=0.8.2->vaex) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in d:\anaconda3\lib\site-packages (from ipython<9->ipympl->vaex-jupyter<0.9,>=0.8.2->vaex) (3.0.43)
# Requirement already satisfied: stack-data in d:\anaconda3\lib\site-packages (from ipython<9->ipympl->vaex-jupyter<0.9,>=0.8.2->vaex) (0.2.0)
# Requirement already satisfied: ipykernel>=4.5.1 in d:\anaconda3\lib\site-packages (from ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (6.28.0)
# Requirement already satisfied: nbformat>=4.2.0 in d:\anaconda3\lib\site-packages (from ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (5.9.2)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in d:\anaconda3\lib\site-packages (from ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (3.5.2)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in d:\anaconda3\lib\site-packages (from ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (3.0.9)
# Requirement already satisfied: mdurl~=0.1 in d:\anaconda3\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->vaex-core~=4.17.1->vaex) (0.1.0)
# Requirement already satisfied: locket in d:\anaconda3\lib\site-packages (from partd>=1.2.0->dask!=2022.4.0->vaex-core~=4.17.1->vaex) (1.0.0)
# Collecting ipydatawidgets>=1.1.1 (from pythreejs>=2.4.0->ipyvolume>=0.4->vaex-jupyter<0.9,>=0.8.2->vaex)
#   Downloading ipydatawidgets-4.3.5-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: anyio<5,>=3.4.0 in d:\anaconda3\lib\site-packages (from starlette<0.38.0,>=0.37.2->fastapi->vaex-server~=0.9.0->vaex) (4.2.0)
# Requirement already satisfied: sniffio>=1.1 in d:\anaconda3\lib\site-packages (from anyio<5,>=3.4.0->starlette<0.38.0,>=0.37.2->fastapi->vaex-server~=0.9.0->vaex) (1.3.0)
# Requirement already satisfied: comm>=0.1.1 in d:\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (0.1.2)
# Requirement already satisfied: debugpy>=1.6.5 in d:\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (1.6.7)
# Requirement already satisfied: jupyter-client>=6.1.12 in d:\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (8.6.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in d:\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (5.5.0)
# Requirement already satisfied: psutil in d:\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (5.9.0)
# Requirement already satisfied: pyzmq>=24 in d:\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (25.1.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in d:\anaconda3\lib\site-packages (from jedi>=0.16->ipython<9->ipympl->vaex-jupyter<0.9,>=0.8.2->vaex) (0.8.3)
# Requirement already satisfied: fastjsonschema in d:\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in d:\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (4.19.2)
# Requirement already satisfied: wcwidth in d:\anaconda3\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython<9->ipympl->vaex-jupyter<0.9,>=0.8.2->vaex) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in d:\anaconda3\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (7.0.8)
# Requirement already satisfied: executing in d:\anaconda3\lib\site-packages (from stack-data->ipython<9->ipympl->vaex-jupyter<0.9,>=0.8.2->vaex) (0.8.3)
# Requirement already satisfied: asttokens in d:\anaconda3\lib\site-packages (from stack-data->ipython<9->ipympl->vaex-jupyter<0.9,>=0.8.2->vaex) (2.0.5)
# Requirement already satisfied: pure-eval in d:\anaconda3\lib\site-packages (from stack-data->ipython<9->ipympl->vaex-jupyter<0.9,>=0.8.2->vaex) (0.2.2)
# Requirement already satisfied: attrs>=22.2.0 in d:\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in d:\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in d:\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in d:\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (0.10.6)
# Requirement already satisfied: platformdirs>=2.5 in d:\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (3.10.0)
# Requirement already satisfied: pywin32>=300 in d:\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (305.1)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in d:\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (2.10.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.22.1 in d:\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (2.25.1)
# Requirement already satisfied: jupyterlab<4.1,>=4.0.2 in d:\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (4.0.11)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in d:\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (0.2.3)
# Requirement already satisfied: argon2-cffi in d:\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (21.3.0)
# Requirement already satisfied: jupyter-events>=0.6.0 in d:\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (0.8.0)
# Requirement already satisfied: jupyter-server-terminals in d:\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (0.4.4)
# Requirement already satisfied: nbconvert>=6.4.4 in d:\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (7.10.0)
# Requirement already satisfied: overrides in d:\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (7.4.0)
# Requirement already satisfied: prometheus-client in d:\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (0.14.1)
# Requirement already satisfied: pywinpty in d:\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (2.0.10)
# Requirement already satisfied: send2trash>=1.8.2 in d:\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in d:\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (0.17.1)
# Requirement already satisfied: websocket-client in d:\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (0.58.0)
# Requirement already satisfied: async-lru>=1.0.0 in d:\anaconda3\lib\site-packages (from jupyterlab<4.1,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (2.0.4)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in d:\anaconda3\lib\site-packages (from jupyterlab<4.1,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (2.2.0)
# Requirement already satisfied: babel>=2.10 in d:\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (2.11.0)
# Requirement already satisfied: json5>=0.9.0 in d:\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (0.9.6)
# Requirement already satisfied: python-json-logger>=2.0.4 in d:\anaconda3\lib\site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (2.0.7)
# Requirement already satisfied: rfc3339-validator in d:\anaconda3\lib\site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in d:\anaconda3\lib\site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (0.1.1)
# Requirement already satisfied: beautifulsoup4 in d:\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (4.12.2)
# Requirement already satisfied: bleach!=5.0.0 in d:\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (4.1.0)
# Requirement already satisfied: defusedxml in d:\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in d:\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (0.1.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in d:\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (2.0.4)
# Requirement already satisfied: nbclient>=0.5.0 in d:\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (0.8.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in d:\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (1.5.0)
# Requirement already satisfied: tinycss2 in d:\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (1.2.1)
# Requirement already satisfied: argon2-cffi-bindings in d:\anaconda3\lib\site-packages (from argon2-cffi->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (21.2.0)
# Requirement already satisfied: webencodings in d:\anaconda3\lib\site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (0.5.1)
# Collecting fqdn (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex)
#   Using cached fqdn-1.5.1-py3-none-any.whl.metadata (1.4 kB)
# Collecting isoduration (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex)
#   Using cached isoduration-20.11.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: jsonpointer>1.13 in d:\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (2.1)
# Collecting uri-template (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex)
#   Using cached uri_template-1.3.0-py3-none-any.whl.metadata (8.8 kB)
# Collecting webcolors>=1.11 (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex)
#   Using cached webcolors-1.13-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: cffi>=1.0.1 in d:\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in d:\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (2.5)
# Requirement already satisfied: pycparser in d:\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (2.21)
# Requirement already satisfied: arrow>=0.15.0 in d:\anaconda3\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (1.2.3)
# Downloading vaex-4.17.0-py3-none-any.whl (4.8 kB)
# Downloading vaex_astro-0.9.3-py3-none-any.whl (20 kB)
# Downloading vaex_hdf5-0.14.1-py3-none-any.whl (16 kB)
# Downloading vaex_jupyter-0.8.2-py3-none-any.whl (43 kB)
#    ---------------------------------------- 0.0/43.2 kB ? eta -:--:--
#    ---------------------------------------- 43.2/43.2 kB 2.2 MB/s eta 0:00:00
# Downloading vaex_ml-0.18.3-py3-none-any.whl (58 kB)
#    ---------------------------------------- 0.0/58.2 kB ? eta -:--:--
#    ---------------------------------------- 58.2/58.2 kB 3.2 MB/s eta 0:00:00
# Downloading vaex_server-0.9.0-py3-none-any.whl (23 kB)
# Downloading vaex_viz-0.5.4-py3-none-any.whl (19 kB)
# Downloading bqplot-0.12.43-py2.py3-none-any.whl (1.2 MB)
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ----- ---------------------------------- 0.2/1.2 MB 5.1 MB/s eta 0:00:01
#    ----------- ---------------------------- 0.4/1.2 MB 4.5 MB/s eta 0:00:01
#    ----------------- ---------------------- 0.5/1.2 MB 4.2 MB/s eta 0:00:01
#    ---------------------- ----------------- 0.7/1.2 MB 4.0 MB/s eta 0:00:01
#    ----------------------------- ---------- 0.9/1.2 MB 4.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 1.1/1.2 MB 4.1 MB/s eta 0:00:01
#    ---------------------------------------- 1.2/1.2 MB 3.9 MB/s eta 0:00:00
# Downloading ipyvolume-0.6.3-py3-none-any.whl (1.6 MB)
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ----- ---------------------------------- 0.2/1.6 MB 4.6 MB/s eta 0:00:01
#    ---------- ----------------------------- 0.4/1.6 MB 4.3 MB/s eta 0:00:01
#    -------------- ------------------------- 0.6/1.6 MB 4.2 MB/s eta 0:00:01
#    -------------------- ------------------- 0.8/1.6 MB 4.3 MB/s eta 0:00:01
#    ------------------------- -------------- 1.0/1.6 MB 4.3 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.2/1.6 MB 4.2 MB/s eta 0:00:01
#    ---------------------------------- ----- 1.4/1.6 MB 4.2 MB/s eta 0:00:01
#    ---------------------------------------  1.6/1.6 MB 4.3 MB/s eta 0:00:01
#    ---------------------------------------- 1.6/1.6 MB 4.1 MB/s eta 0:00:00
# Downloading ipyvuetify-1.9.4-py2.py3-none-any.whl (6.1 MB)
#    ---------------------------------------- 0.0/6.1 MB ? eta -:--:--
#    - -------------------------------------- 0.2/6.1 MB 5.6 MB/s eta 0:00:02
#    -- ------------------------------------- 0.4/6.1 MB 4.1 MB/s eta 0:00:02
#    ---- ----------------------------------- 0.6/6.1 MB 4.8 MB/s eta 0:00:02
#    ----- ---------------------------------- 0.8/6.1 MB 4.4 MB/s eta 0:00:02
#    ------ --------------------------------- 1.1/6.1 MB 4.4 MB/s eta 0:00:02
#    -------- ------------------------------- 1.3/6.1 MB 4.5 MB/s eta 0:00:02
#    --------- ------------------------------ 1.5/6.1 MB 4.7 MB/s eta 0:00:01
#    ----------- ---------------------------- 1.7/6.1 MB 4.7 MB/s eta 0:00:01
#    ------------ --------------------------- 1.9/6.1 MB 4.6 MB/s eta 0:00:01
#    ------------- -------------------------- 2.1/6.1 MB 4.7 MB/s eta 0:00:01
#    --------------- ------------------------ 2.3/6.1 MB 4.6 MB/s eta 0:00:01
#    ---------------- ----------------------- 2.5/6.1 MB 4.6 MB/s eta 0:00:01
#    ------------------ --------------------- 2.8/6.1 MB 4.6 MB/s eta 0:00:01
#    ------------------- -------------------- 3.0/6.1 MB 4.6 MB/s eta 0:00:01
#    --------------------- ------------------ 3.2/6.1 MB 4.7 MB/s eta 0:00:01
#    ---------------------- ----------------- 3.4/6.1 MB 4.7 MB/s eta 0:00:01
#    ------------------------ --------------- 3.7/6.1 MB 4.7 MB/s eta 0:00:01
#    ------------------------- -------------- 3.9/6.1 MB 4.6 MB/s eta 0:00:01
#    -------------------------- ------------- 4.1/6.1 MB 4.6 MB/s eta 0:00:01
#    ---------------------------- ----------- 4.3/6.1 MB 4.6 MB/s eta 0:00:01
#    ----------------------------- ---------- 4.5/6.1 MB 4.6 MB/s eta 0:00:01
#    ------------------------------- -------- 4.7/6.1 MB 4.6 MB/s eta 0:00:01
#    -------------------------------- ------- 5.0/6.1 MB 4.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 5.2/6.1 MB 4.7 MB/s eta 0:00:01
#    ----------------------------------- ---- 5.4/6.1 MB 4.7 MB/s eta 0:00:01
#    ------------------------------------- -- 5.6/6.1 MB 4.7 MB/s eta 0:00:01
#    -------------------------------------- - 5.9/6.1 MB 4.7 MB/s eta 0:00:01
#    ---------------------------------------  6.1/6.1 MB 4.7 MB/s eta 0:00:01
#    ---------------------------------------- 6.1/6.1 MB 4.6 MB/s eta 0:00:00
# Downloading blake3-0.4.1-cp311-none-win_amd64.whl (210 kB)
#    ---------------------------------------- 0.0/210.1 kB ? eta -:--:--
#    -------------------------------------- - 204.8/210.1 kB 4.1 MB/s eta 0:00:01
#    ---------------------------------------- 210.1/210.1 kB 3.2 MB/s eta 0:00:00
# Downloading fastapi-0.110.2-py3-none-any.whl (91 kB)
#    ---------------------------------------- 0.0/91.9 kB ? eta -:--:--
#    ---------------------------------------- 91.9/91.9 kB 5.4 MB/s eta 0:00:00
# Downloading ipyleaflet-0.19.0-py3-none-any.whl (30 kB)
# Downloading ipympl-0.9.4-py3-none-any.whl (516 kB)
#    ---------------------------------------- 0.0/516.3 kB ? eta -:--:--
#    --------------- ------------------------ 204.8/516.3 kB 6.3 MB/s eta 0:00:01
#    --------------------------------- ------ 430.1/516.3 kB 5.4 MB/s eta 0:00:01
#    ---------------------------------------- 516.3/516.3 kB 4.6 MB/s eta 0:00:00
# Downloading progressbar2-4.4.2-py3-none-any.whl (56 kB)
#    ---------------------------------------- 0.0/56.8 kB ? eta -:--:--
#    ---------------------------------------- 56.8/56.8 kB 2.9 MB/s eta 0:00:00
# Downloading branca-0.7.1-py3-none-any.whl (25 kB)
# Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# Downloading httptools-0.6.1-cp311-cp311-win_amd64.whl (55 kB)
#    ---------------------------------------- 0.0/55.4 kB ? eta -:--:--
#    ---------------------------------------- 55.4/55.4 kB ? eta 0:00:00
# Downloading ipyvue-1.11.0-py2.py3-none-any.whl (2.7 MB)
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.7 MB 5.9 MB/s eta 0:00:01
#    ------- -------------------------------- 0.5/2.7 MB 5.4 MB/s eta 0:00:01
#    ----------- ---------------------------- 0.7/2.7 MB 5.2 MB/s eta 0:00:01
#    -------------- ------------------------- 1.0/2.7 MB 5.2 MB/s eta 0:00:01
#    ------------------ --------------------- 1.2/2.7 MB 5.5 MB/s eta 0:00:01
#    --------------------- ------------------ 1.5/2.7 MB 5.1 MB/s eta 0:00:01
#    ------------------------- -------------- 1.7/2.7 MB 5.3 MB/s eta 0:00:01
#    ---------------------------- ----------- 1.9/2.7 MB 5.1 MB/s eta 0:00:01
#    -------------------------------- ------- 2.2/2.7 MB 5.1 MB/s eta 0:00:01
#    ------------------------------------ --- 2.4/2.7 MB 5.1 MB/s eta 0:00:01
#    ---------------------------------------  2.7/2.7 MB 5.1 MB/s eta 0:00:01
#    ---------------------------------------- 2.7/2.7 MB 4.9 MB/s eta 0:00:00
# Downloading jupyter_leaflet-0.19.0-py3-none-any.whl (1.1 MB)
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ------- -------------------------------- 0.2/1.1 MB 4.1 MB/s eta 0:00:01
#    ----------------- ---------------------- 0.5/1.1 MB 5.9 MB/s eta 0:00:01
#    --------------------------- ------------ 0.7/1.1 MB 5.2 MB/s eta 0:00:01
#    ------------------------------------ --- 1.0/1.1 MB 5.2 MB/s eta 0:00:01
#    ---------------------------------------- 1.1/1.1 MB 4.9 MB/s eta 0:00:00
# Downloading python_utils-3.8.2-py2.py3-none-any.whl (27 kB)
# Downloading pythreejs-2.4.2-py3-none-any.whl (3.4 MB)
#    ---------------------------------------- 0.0/3.4 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/3.4 MB 8.3 MB/s eta 0:00:01
#    ------ --------------------------------- 0.5/3.4 MB 6.7 MB/s eta 0:00:01
#    --------- ------------------------------ 0.8/3.4 MB 6.2 MB/s eta 0:00:01
#    ------------ --------------------------- 1.0/3.4 MB 6.0 MB/s eta 0:00:01
#    --------------- ------------------------ 1.3/3.4 MB 5.8 MB/s eta 0:00:01
#    ------------------ --------------------- 1.5/3.4 MB 5.7 MB/s eta 0:00:01
#    --------------------- ------------------ 1.8/3.4 MB 5.7 MB/s eta 0:00:01
#    ------------------------ --------------- 2.0/3.4 MB 5.6 MB/s eta 0:00:01
#    --------------------------- ------------ 2.3/3.4 MB 5.6 MB/s eta 0:00:01
#    ------------------------------ --------- 2.5/3.4 MB 5.6 MB/s eta 0:00:01
#    --------------------------------- ------ 2.8/3.4 MB 5.6 MB/s eta 0:00:01
#    ------------------------------------ --- 3.1/3.4 MB 5.6 MB/s eta 0:00:01
#    ---------------------------------------  3.3/3.4 MB 5.6 MB/s eta 0:00:01
#    ---------------------------------------- 3.4/3.4 MB 5.4 MB/s eta 0:00:00
# Downloading starlette-0.37.2-py3-none-any.whl (71 kB)
#    ---------------------------------------- 0.0/71.9 kB ? eta -:--:--
#    ---------------------------------------- 71.9/71.9 kB 3.9 MB/s eta 0:00:00
# Downloading traittypes-0.2.1-py2.py3-none-any.whl (8.6 kB)
# Downloading watchfiles-0.21.0-cp311-none-win_amd64.whl (280 kB)
#    ---------------------------------------- 0.0/280.1 kB ? eta -:--:--
#    -------------------------------- ------- 225.3/280.1 kB 6.9 MB/s eta 0:00:01
#    ---------------------------------------- 280.1/280.1 kB 5.7 MB/s eta 0:00:00
# Downloading ipywebrtc-0.6.0-py2.py3-none-any.whl (260 kB)
#    ---------------------------------------- 0.0/260.7 kB ? eta -:--:--
#    ------------------------------------- -- 245.8/260.7 kB 7.6 MB/s eta 0:00:01
#    ---------------------------------------- 260.7/260.7 kB 5.4 MB/s eta 0:00:00
# Downloading uvicorn-0.29.0-py3-none-any.whl (60 kB)
#    ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#    ---------------------------------------- 60.8/60.8 kB ? eta 0:00:00
# Downloading ipydatawidgets-4.3.5-py2.py3-none-any.whl (271 kB)
#    ---------------------------------------- 0.0/271.7 kB ? eta -:--:--
#    ---------------------------------- ----- 235.5/271.7 kB 7.0 MB/s eta 0:00:01
#    ---------------------------------------- 271.7/271.7 kB 5.6 MB/s eta 0:00:00
# Using cached webcolors-1.13-py3-none-any.whl (14 kB)
# Using cached fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Using cached isoduration-20.11.0-py3-none-any.whl (11 kB)
# Using cached uri_template-1.3.0-py3-none-any.whl (11 kB)
# Building wheels for collected packages: vaex-core, frozendict, aplus
#   Building wheel for vaex-core (pyproject.toml): started
#   Building wheel for vaex-core (pyproject.toml): finished with status 'error'
#   Building wheel for frozendict (pyproject.toml): started
#   Building wheel for frozendict (pyproject.toml): finished with status 'done'
#   Created wheel for frozendict: filename=frozendict-2.4.2-cp311-cp311-win_amd64.whl size=15543 sha256=b8949c89d88f17858c0b0e82a91c1aee5b3186cf5e383d258babe6fd7ac4c207
#   Stored in directory: c:\users\антоша\appdata\local\pip\cache\wheels\b6\d6\b5\da9ad65b3c11d2d2f3245b0b2476231dc58a2a91768c5ec755
#   Building wheel for aplus (setup.py): started
#   Building wheel for aplus (setup.py): finished with status 'done'
#   Created wheel for aplus: filename=aplus-0.11.0-py3-none-any.whl size=4373 sha256=85f383aeecde79bd1ccb60f3901a89459e96cb29ff04ad04ab36744689849825
#   Stored in directory: c:\users\антоша\appdata\local\pip\cache\wheels\74\1c\74\052c2629ccf684eaf53e267e24052316d65242c3e02fb79a68
# Successfully built frozendict aplus
# Failed to build vaex-core
#   error: subprocess-exited-with-error
#
#   Building wheel for vaex-core (pyproject.toml) did not run successfully.
#   exit code: 1
#
#   [191 lines of output]
#   <string>:4: DeprecationWarning: the imp module is deprecated in favour of importlib and slated for removal in Python 3.12; see the module's documentation for alternative uses
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-cpython-311
#   creating build\lib.win-amd64-cpython-311\vaex
#   copying vaex\agg.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\array_types.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\asyncio.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\benchmark.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\cache.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\column.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\config.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\convert.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\cpu.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\csv.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\dataframe.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\dataframe_protocol.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\dataset.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\dataset_misc.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\dataset_mmap.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\dataset_utils.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\datatype.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\datatype_test.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\delayed.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\docstrings.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\encoding.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\events.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\execution.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\export.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\expression.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\expresso.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\formatting.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\functions.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\geo.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\grids.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\groupby.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\hash.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\image.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\itertools.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\join.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\json.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\kld.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\legacy.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\logging.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\memory.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\meta.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\metal.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\minisettings.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\misc_cmdline.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\multiprocessing.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\multithreading.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\parallelize.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\progress.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\promise.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\registry.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\rolling.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\samp.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\schema.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\scopes.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\selections.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\serialize.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\settings.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\shift.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\stat.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\strings.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\struct.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\tasks.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\utils.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\version.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\_version.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\__init__.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\__main__.py -> build\lib.win-amd64-cpython-311\vaex
#   creating build\lib.win-amd64-cpython-311\vaex\arrow
#   copying vaex\arrow\convert.py -> build\lib.win-amd64-cpython-311\vaex\arrow
#   copying vaex\arrow\dataset.py -> build\lib.win-amd64-cpython-311\vaex\arrow
#   copying vaex\arrow\numpy_dispatch.py -> build\lib.win-amd64-cpython-311\vaex\arrow
#   copying vaex\arrow\opener.py -> build\lib.win-amd64-cpython-311\vaex\arrow
#   copying vaex\arrow\utils.py -> build\lib.win-amd64-cpython-311\vaex\arrow
#   copying vaex\arrow\utils_test.py -> build\lib.win-amd64-cpython-311\vaex\arrow
#   copying vaex\arrow\_version.py -> build\lib.win-amd64-cpython-311\vaex\arrow
#   creating build\lib.win-amd64-cpython-311\vaex\core
#   copying vaex\core\_version.py -> build\lib.win-amd64-cpython-311\vaex\core
#   copying vaex\core\__init__.py -> build\lib.win-amd64-cpython-311\vaex\core
#   creating build\lib.win-amd64-cpython-311\vaex\file
#   copying vaex\file\asyncio.py -> build\lib.win-amd64-cpython-311\vaex\file
#   copying vaex\file\cache.py -> build\lib.win-amd64-cpython-311\vaex\file
#   copying vaex\file\column.py -> build\lib.win-amd64-cpython-311\vaex\file
#   copying vaex\file\gcs.py -> build\lib.win-amd64-cpython-311\vaex\file
#   copying vaex\file\s3.py -> build\lib.win-amd64-cpython-311\vaex\file
#   copying vaex\file\s3arrow.py -> build\lib.win-amd64-cpython-311\vaex\file
#   copying vaex\file\s3fs.py -> build\lib.win-amd64-cpython-311\vaex\file
#   copying vaex\file\s3_test.py -> build\lib.win-amd64-cpython-311\vaex\file
#   copying vaex\file\__init__.py -> build\lib.win-amd64-cpython-311\vaex\file
#   creating build\lib.win-amd64-cpython-311\vaex\test
#   copying vaex\test\all.py -> build\lib.win-amd64-cpython-311\vaex\test
#   copying vaex\test\cmodule.py -> build\lib.win-amd64-cpython-311\vaex\test
#   copying vaex\test\dataset.py -> build\lib.win-amd64-cpython-311\vaex\test
#   copying vaex\test\expresso.py -> build\lib.win-amd64-cpython-311\vaex\test
#   copying vaex\test\misc.py -> build\lib.win-amd64-cpython-311\vaex\test
#   copying vaex\test\plot.py -> build\lib.win-amd64-cpython-311\vaex\test
#   copying vaex\test\ui.py -> build\lib.win-amd64-cpython-311\vaex\test
#   copying vaex\test\__init__.py -> build\lib.win-amd64-cpython-311\vaex\test
#   copying vaex\test\__main__.py -> build\lib.win-amd64-cpython-311\vaex\test
#   creating build\lib.win-amd64-cpython-311\vaex\ext
#   copying vaex\ext\bokeh.py -> build\lib.win-amd64-cpython-311\vaex\ext
#   copying vaex\ext\common.py -> build\lib.win-amd64-cpython-311\vaex\ext
#   copying vaex\ext\ipyvolume.py -> build\lib.win-amd64-cpython-311\vaex\ext
#   copying vaex\ext\jprops.py -> build\lib.win-amd64-cpython-311\vaex\ext
#   copying vaex\ext\readcol.py -> build\lib.win-amd64-cpython-311\vaex\ext
#   copying vaex\ext\__init__.py -> build\lib.win-amd64-cpython-311\vaex\ext
#   creating build\lib.win-amd64-cpython-311\vaex\misc
#   copying vaex\misc\expressions.py -> build\lib.win-amd64-cpython-311\vaex\misc
#   copying vaex\misc\ordereddict.py -> build\lib.win-amd64-cpython-311\vaex\misc
#   copying vaex\misc\pandawrap.py -> build\lib.win-amd64-cpython-311\vaex\misc
#   copying vaex\misc\parallelize.py -> build\lib.win-amd64-cpython-311\vaex\misc
#   copying vaex\misc\progressbar.py -> build\lib.win-amd64-cpython-311\vaex\misc
#   copying vaex\misc\samp.py -> build\lib.win-amd64-cpython-311\vaex\misc
#   copying vaex\misc\__init__.py -> build\lib.win-amd64-cpython-311\vaex\misc
#   creating build\lib.win-amd64-cpython-311\vaex\datasets
#   copying vaex\datasets\__init__.py -> build\lib.win-amd64-cpython-311\vaex\datasets
#   running egg_info
#   writing vaex_core.egg-info\PKG-INFO
#   writing dependency_links to vaex_core.egg-info\dependency_links.txt
#   writing entry points to vaex_core.egg-info\entry_points.txt
#   writing requirements to vaex_core.egg-info\requires.txt
#   writing top-level names to vaex_core.egg-info\top_level.txt
#   reading manifest file 'vaex_core.egg-info\SOURCES.txt'
#   reading manifest template 'MANIFEST.in'
#   warning: no files found matching '*.c' under directory 'vendor'
#   warning: no files found matching '*.h' under directory 'src'
#   warning: no files found matching '*.c' under directory 'src'
#   adding license file 'LICENSE.txt'
#   writing manifest file 'vaex_core.egg-info\SOURCES.txt'
#   C:\Users\Антоша\AppData\Local\Temp\pip-build-env-p1w38qca\overlay\Lib\site-packages\setuptools\command\build_py.py:207: _Warning: Package 'vaex.test.files' is absent from the `packages` configuration.
#   !!
#
#           ********************************************************************************
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'vaex.test.files' as an importable package[^1],
#           but it is absent from setuptools' `packages` configuration.
#
#           This leads to an ambiguous overall configuration. If you want to distribute this
#           package, please make sure that 'vaex.test.files' is explicitly added
#           to the `packages` configuration field.
#
#           Alternatively, you can also rely on setuptools' discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" on setuptools documentation page:
#
#           - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#           If you don't want 'vaex.test.files' to be distributed and are
#           already explicitly excluding 'vaex.test.files' via
#           `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#           you can try to use `exclude_package_data`, or `include-package-data=False` in
#           combination with a more fine grained `package-data` configuration.
#
#           You can read more about "package data files" on setuptools documentation page:
#
#           - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#           [^1]: For Python, any directory (with suitable naming) can be imported,
#                 even if it does not contain any `.py` files.
#                 On the other hand, currently there is no concept of package data
#                 directory, all directories are treated like packages.
#           ********************************************************************************
#
#   !!
#     check.warn(importable)
#   copying vaex\pcre.dll -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\pcrecpp.dll -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\vcruntime140_1.dll -> build\lib.win-amd64-cpython-311\vaex
#   creating build\lib.win-amd64-cpython-311\vaex\test\files
#   copying vaex\test\files\gaia-small-colfits-basic.fits -> build\lib.win-amd64-cpython-311\vaex\test\files
#   copying vaex\test\files\gaia-small-colfits-plus.fits -> build\lib.win-amd64-cpython-311\vaex\test\files
#   copying vaex\test\files\gaia-small-fits-basic.fits -> build\lib.win-amd64-cpython-311\vaex\test\files
#   copying vaex\test\files\gaia-small-fits-plus.fits -> build\lib.win-amd64-cpython-311\vaex\test\files
#   copying vaex\test\files\gaia-small-votable.vot -> build\lib.win-amd64-cpython-311\vaex\test\files
#   copying vaex\test\files\default_amuse_plummer.hdf5 -> build\lib.win-amd64-cpython-311\vaex\test\files
#   copying vaex\datasets\iris.hdf5 -> build\lib.win-amd64-cpython-311\vaex\datasets
#   copying vaex\datasets\titanic.hdf5 -> build\lib.win-amd64-cpython-311\vaex\datasets
#   running build_ext
#   building 'vaex.vaexfast' extension
#   error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for vaex-core
# ERROR: Could not build wheels for vaex-core, which is required to install pyproject.toml-based projects

# %%
import vaex
 name 'np' is not defined
# Загрузка данных из CSV файла с использованием Vaex
df = vaex.from_csv('D:\МИРЭА\Машинное обучение\Пр5\water_dataset', convert=True, chunk_size=5_000_000)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 import vaex
#       3 # Загрузка данных из CSV файла с использованием Vaex
#       4 df = vaex.from_csv('D:\МИРЭА\Машинное обучение\Пр5\water_dataset', convert=True, chunk_size=5_000_000)
#
# ModuleNotFoundError: No module named 'vaex'

# %%
import numpy as np

with open('D:\МИРЭА\Машинное обучение\Пр5\water_dataset', 'rb') as file:
    data = file.read()

# Преобразование байтов в массивы numpy
categories = np.frombuffer(data, dtype=np.int32)
amounts = np.frombuffer(data, dtype=np.float64)

# Создание DataFrame Vaex из массивов numpy
df = vaex.from_arrays(category=categories, amount=amounts)

# Группировка и агрегация данных с использованием Vaex
result = df.groupby(df.category, agg=vaex.agg.sum(df.amount))

print(result)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 7
#       4     data = file.read()
#       6 # Преобразование байтов в массивы numpy
# ----> 7 categories = np.frombuffer(data, dtype=np.int32)
#       8 amounts = np.frombuffer(data, dtype=np.float64)
#      10 # Создание DataFrame Vaex из массивов numpy
#
# ValueError: buffer size must be a multiple of element size

# %%
# !pip install vaex
# Out:
# Collecting vaex
#   Using cached vaex-4.17.0-py3-none-any.whl.metadata (6.0 kB)
# Collecting vaex-core~=4.17.1 (from vaex)
#   Using cached vaex-core-4.17.1.tar.gz (2.5 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting vaex-astro<0.10,>=0.9.3 (from vaex)
#   Using cached vaex_astro-0.9.3-py3-none-any.whl.metadata (345 bytes)
# Collecting vaex-hdf5<0.15,>=0.13.0 (from vaex)
#   Using cached vaex_hdf5-0.14.1-py3-none-any.whl.metadata (321 bytes)
# Collecting vaex-viz<0.6,>=0.5.4 (from vaex)
#   Using cached vaex_viz-0.5.4-py3-none-any.whl.metadata (345 bytes)
# Collecting vaex-server~=0.9.0 (from vaex)
#   Using cached vaex_server-0.9.0-py3-none-any.whl.metadata (430 bytes)
# Collecting vaex-jupyter<0.9,>=0.8.2 (from vaex)
#   Using cached vaex_jupyter-0.8.2-py3-none-any.whl.metadata (517 bytes)
# Collecting vaex-ml<0.19,>=0.18.3 (from vaex)
#   Using cached vaex_ml-0.18.3-py3-none-any.whl.metadata (485 bytes)
# Requirement already satisfied: astropy in d:\anaconda3\lib\site-packages (from vaex-astro<0.10,>=0.9.3->vaex) (5.3.4)
# Requirement already satisfied: numpy>=1.16 in d:\anaconda3\lib\site-packages (from vaex-core~=4.17.1->vaex) (1.26.4)
# Collecting aplus (from vaex-core~=4.17.1->vaex)
#   Using cached aplus-0.11.0-py3-none-any.whl
# Requirement already satisfied: tabulate>=0.8.3 in d:\anaconda3\lib\site-packages (from vaex-core~=4.17.1->vaex) (0.9.0)
# Requirement already satisfied: future>=0.15.2 in d:\anaconda3\lib\site-packages (from vaex-core~=4.17.1->vaex) (0.18.3)
# Requirement already satisfied: pyyaml in d:\anaconda3\lib\site-packages (from vaex-core~=4.17.1->vaex) (6.0.1)
# Collecting progressbar2 (from vaex-core~=4.17.1->vaex)
#   Using cached progressbar2-4.4.2-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: requests in d:\anaconda3\lib\site-packages (from vaex-core~=4.17.1->vaex) (2.31.0)
# Requirement already satisfied: six in d:\anaconda3\lib\site-packages (from vaex-core~=4.17.1->vaex) (1.16.0)
# Requirement already satisfied: cloudpickle in d:\anaconda3\lib\site-packages (from vaex-core~=4.17.1->vaex) (2.2.1)
# Requirement already satisfied: pandas in d:\anaconda3\lib\site-packages (from vaex-core~=4.17.1->vaex) (2.1.4)
# Requirement already satisfied: dask!=2022.4.0 in d:\anaconda3\lib\site-packages (from vaex-core~=4.17.1->vaex) (2023.11.0)
# Requirement already satisfied: nest-asyncio>=1.3.3 in d:\anaconda3\lib\site-packages (from vaex-core~=4.17.1->vaex) (1.6.0)
# Requirement already satisfied: pyarrow>=5.0.0 in d:\anaconda3\lib\site-packages (from vaex-core~=4.17.1->vaex) (14.0.2)
# Collecting frozendict!=2.2.0 (from vaex-core~=4.17.1->vaex)
#   Using cached frozendict-2.4.2-cp311-cp311-win_amd64.whl
# Collecting blake3 (from vaex-core~=4.17.1->vaex)
#   Using cached blake3-0.4.1-cp311-none-win_amd64.whl.metadata (4.2 kB)
# Requirement already satisfied: filelock in d:\anaconda3\lib\site-packages (from vaex-core~=4.17.1->vaex) (3.13.1)
# Requirement already satisfied: pydantic>=1.8.0 in d:\anaconda3\lib\site-packages (from vaex-core~=4.17.1->vaex) (1.10.12)
# Requirement already satisfied: rich in d:\anaconda3\lib\site-packages (from vaex-core~=4.17.1->vaex) (13.3.5)
# Requirement already satisfied: h5py>=2.9 in d:\anaconda3\lib\site-packages (from vaex-hdf5<0.15,>=0.13.0->vaex) (3.9.0)
# Collecting bqplot>=0.10.1 (from vaex-jupyter<0.9,>=0.8.2->vaex)
#   Using cached bqplot-0.12.43-py2.py3-none-any.whl.metadata (6.4 kB)
# Collecting ipyvolume>=0.4 (from vaex-jupyter<0.9,>=0.8.2->vaex)
#   Using cached ipyvolume-0.6.3-py3-none-any.whl.metadata (2.3 kB)
# Collecting ipyleaflet (from vaex-jupyter<0.9,>=0.8.2->vaex)
#   Using cached ipyleaflet-0.19.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting ipympl (from vaex-jupyter<0.9,>=0.8.2->vaex)
#   Using cached ipympl-0.9.4-py3-none-any.whl.metadata (8.7 kB)
# Collecting ipyvuetify<2,>=1.2.2 (from vaex-jupyter<0.9,>=0.8.2->vaex)
#   Using cached ipyvuetify-1.9.4-py2.py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: xarray in d:\anaconda3\lib\site-packages (from vaex-jupyter<0.9,>=0.8.2->vaex) (2023.6.0)
# Requirement already satisfied: numba in d:\anaconda3\lib\site-packages (from vaex-ml<0.19,>=0.18.3->vaex) (0.59.0)
# Requirement already satisfied: traitlets in d:\anaconda3\lib\site-packages (from vaex-ml<0.19,>=0.18.3->vaex) (5.7.1)
# Requirement already satisfied: jinja2 in d:\anaconda3\lib\site-packages (from vaex-ml<0.19,>=0.18.3->vaex) (3.1.3)
# Requirement already satisfied: tornado>4.1 in d:\anaconda3\lib\site-packages (from vaex-server~=0.9.0->vaex) (6.3.3)
# Requirement already satisfied: cachetools in d:\anaconda3\lib\site-packages (from vaex-server~=0.9.0->vaex) (4.2.2)
# Collecting fastapi (from vaex-server~=0.9.0->vaex)
#   Using cached fastapi-0.110.2-py3-none-any.whl.metadata (24 kB)
# Collecting uvicorn[standard] (from vaex-server~=0.9.0->vaex)
#   Using cached uvicorn-0.29.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: matplotlib>=1.3.1 in d:\anaconda3\lib\site-packages (from vaex-viz<0.6,>=0.5.4->vaex) (3.8.0)
# Requirement already satisfied: pillow in d:\anaconda3\lib\site-packages (from vaex-viz<0.6,>=0.5.4->vaex) (10.2.0)
# Requirement already satisfied: ipywidgets<9,>=7.5.0 in d:\anaconda3\lib\site-packages (from bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (7.6.5)
# Collecting traittypes>=0.0.6 (from bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex)
#   Using cached traittypes-0.2.1-py2.py3-none-any.whl.metadata (1.0 kB)
# Requirement already satisfied: click>=8.1 in d:\anaconda3\lib\site-packages (from dask!=2022.4.0->vaex-core~=4.17.1->vaex) (8.1.7)
# Requirement already satisfied: fsspec>=2021.09.0 in d:\anaconda3\lib\site-packages (from dask!=2022.4.0->vaex-core~=4.17.1->vaex) (2023.10.0)
# Requirement already satisfied: packaging>=20.0 in d:\anaconda3\lib\site-packages (from dask!=2022.4.0->vaex-core~=4.17.1->vaex) (23.1)
# Requirement already satisfied: partd>=1.2.0 in d:\anaconda3\lib\site-packages (from dask!=2022.4.0->vaex-core~=4.17.1->vaex) (1.4.1)
# Requirement already satisfied: toolz>=0.10.0 in d:\anaconda3\lib\site-packages (from dask!=2022.4.0->vaex-core~=4.17.1->vaex) (0.12.0)
# Requirement already satisfied: importlib-metadata>=4.13.0 in d:\anaconda3\lib\site-packages (from dask!=2022.4.0->vaex-core~=4.17.1->vaex) (7.0.1)
# Collecting ipywebrtc (from ipyvolume>=0.4->vaex-jupyter<0.9,>=0.8.2->vaex)
#   Using cached ipywebrtc-0.6.0-py2.py3-none-any.whl.metadata (825 bytes)
# Collecting ipyvue>=1.7.0 (from ipyvolume>=0.4->vaex-jupyter<0.9,>=0.8.2->vaex)
#   Using cached ipyvue-1.11.0-py2.py3-none-any.whl.metadata (1.1 kB)
# Collecting pythreejs>=2.4.0 (from ipyvolume>=0.4->vaex-jupyter<0.9,>=0.8.2->vaex)
#   Using cached pythreejs-2.4.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: contourpy>=1.0.1 in d:\anaconda3\lib\site-packages (from matplotlib>=1.3.1->vaex-viz<0.6,>=0.5.4->vaex) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in d:\anaconda3\lib\site-packages (from matplotlib>=1.3.1->vaex-viz<0.6,>=0.5.4->vaex) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in d:\anaconda3\lib\site-packages (from matplotlib>=1.3.1->vaex-viz<0.6,>=0.5.4->vaex) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\anaconda3\lib\site-packages (from matplotlib>=1.3.1->vaex-viz<0.6,>=0.5.4->vaex) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\anaconda3\lib\site-packages (from matplotlib>=1.3.1->vaex-viz<0.6,>=0.5.4->vaex) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in d:\anaconda3\lib\site-packages (from matplotlib>=1.3.1->vaex-viz<0.6,>=0.5.4->vaex) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in d:\anaconda3\lib\site-packages (from pandas->vaex-core~=4.17.1->vaex) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in d:\anaconda3\lib\site-packages (from pandas->vaex-core~=4.17.1->vaex) (2023.3)
# Requirement already satisfied: typing-extensions>=4.2.0 in d:\anaconda3\lib\site-packages (from pydantic>=1.8.0->vaex-core~=4.17.1->vaex) (4.9.0)
# Requirement already satisfied: pyerfa>=2.0 in d:\anaconda3\lib\site-packages (from astropy->vaex-astro<0.10,>=0.9.3->vaex) (2.0.0)
# Collecting starlette<0.38.0,>=0.37.2 (from fastapi->vaex-server~=0.9.0->vaex)
#   Using cached starlette-0.37.2-py3-none-any.whl.metadata (5.9 kB)
# Collecting branca>=0.5.0 (from ipyleaflet->vaex-jupyter<0.9,>=0.8.2->vaex)
#   Downloading branca-0.7.2-py3-none-any.whl.metadata (1.5 kB)
# Collecting jupyter-leaflet<0.20,>=0.19 (from ipyleaflet->vaex-jupyter<0.9,>=0.8.2->vaex)
#   Using cached jupyter_leaflet-0.19.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: xyzservices>=2021.8.1 in d:\anaconda3\lib\site-packages (from ipyleaflet->vaex-jupyter<0.9,>=0.8.2->vaex) (2022.9.0)
# Requirement already satisfied: ipython-genutils in d:\anaconda3\lib\site-packages (from ipympl->vaex-jupyter<0.9,>=0.8.2->vaex) (0.2.0)
# Requirement already satisfied: ipython<9 in d:\anaconda3\lib\site-packages (from ipympl->vaex-jupyter<0.9,>=0.8.2->vaex) (8.20.0)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\anaconda3\lib\site-packages (from jinja2->vaex-ml<0.19,>=0.18.3->vaex) (2.1.3)
# Requirement already satisfied: llvmlite<0.43,>=0.42.0dev0 in d:\anaconda3\lib\site-packages (from numba->vaex-ml<0.19,>=0.18.3->vaex) (0.42.0)
# Collecting python-utils>=3.8.1 (from progressbar2->vaex-core~=4.17.1->vaex)
#   Using cached python_utils-3.8.2-py2.py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\anaconda3\lib\site-packages (from requests->vaex-core~=4.17.1->vaex) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\anaconda3\lib\site-packages (from requests->vaex-core~=4.17.1->vaex) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\anaconda3\lib\site-packages (from requests->vaex-core~=4.17.1->vaex) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda3\lib\site-packages (from requests->vaex-core~=4.17.1->vaex) (2024.2.2)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in d:\anaconda3\lib\site-packages (from rich->vaex-core~=4.17.1->vaex) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in d:\anaconda3\lib\site-packages (from rich->vaex-core~=4.17.1->vaex) (2.15.1)
# Collecting h11>=0.8 (from uvicorn[standard]->vaex-server~=0.9.0->vaex)
#   Using cached h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: colorama>=0.4 in d:\anaconda3\lib\site-packages (from uvicorn[standard]->vaex-server~=0.9.0->vaex) (0.4.6)
# Collecting httptools>=0.5.0 (from uvicorn[standard]->vaex-server~=0.9.0->vaex)
#   Using cached httptools-0.6.1-cp311-cp311-win_amd64.whl.metadata (3.7 kB)
# Requirement already satisfied: python-dotenv>=0.13 in d:\anaconda3\lib\site-packages (from uvicorn[standard]->vaex-server~=0.9.0->vaex) (0.21.0)
# Collecting watchfiles>=0.13 (from uvicorn[standard]->vaex-server~=0.9.0->vaex)
#   Using cached watchfiles-0.21.0-cp311-none-win_amd64.whl.metadata (5.0 kB)
# Requirement already satisfied: websockets>=10.4 in d:\anaconda3\lib\site-packages (from uvicorn[standard]->vaex-server~=0.9.0->vaex) (10.4)
# Requirement already satisfied: zipp>=0.5 in d:\anaconda3\lib\site-packages (from importlib-metadata>=4.13.0->dask!=2022.4.0->vaex-core~=4.17.1->vaex) (3.17.0)
# Requirement already satisfied: decorator in d:\anaconda3\lib\site-packages (from ipython<9->ipympl->vaex-jupyter<0.9,>=0.8.2->vaex) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in d:\anaconda3\lib\site-packages (from ipython<9->ipympl->vaex-jupyter<0.9,>=0.8.2->vaex) (0.18.1)
# Requirement already satisfied: matplotlib-inline in d:\anaconda3\lib\site-packages (from ipython<9->ipympl->vaex-jupyter<0.9,>=0.8.2->vaex) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in d:\anaconda3\lib\site-packages (from ipython<9->ipympl->vaex-jupyter<0.9,>=0.8.2->vaex) (3.0.43)
# Requirement already satisfied: stack-data in d:\anaconda3\lib\site-packages (from ipython<9->ipympl->vaex-jupyter<0.9,>=0.8.2->vaex) (0.2.0)
# Requirement already satisfied: ipykernel>=4.5.1 in d:\anaconda3\lib\site-packages (from ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (6.28.0)
# Requirement already satisfied: nbformat>=4.2.0 in d:\anaconda3\lib\site-packages (from ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (5.9.2)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in d:\anaconda3\lib\site-packages (from ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (3.5.2)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in d:\anaconda3\lib\site-packages (from ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (3.0.9)
# Requirement already satisfied: mdurl~=0.1 in d:\anaconda3\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->vaex-core~=4.17.1->vaex) (0.1.0)
# Requirement already satisfied: locket in d:\anaconda3\lib\site-packages (from partd>=1.2.0->dask!=2022.4.0->vaex-core~=4.17.1->vaex) (1.0.0)
# Collecting ipydatawidgets>=1.1.1 (from pythreejs>=2.4.0->ipyvolume>=0.4->vaex-jupyter<0.9,>=0.8.2->vaex)
#   Using cached ipydatawidgets-4.3.5-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: anyio<5,>=3.4.0 in d:\anaconda3\lib\site-packages (from starlette<0.38.0,>=0.37.2->fastapi->vaex-server~=0.9.0->vaex) (4.2.0)
# Requirement already satisfied: sniffio>=1.1 in d:\anaconda3\lib\site-packages (from anyio<5,>=3.4.0->starlette<0.38.0,>=0.37.2->fastapi->vaex-server~=0.9.0->vaex) (1.3.0)
# Requirement already satisfied: comm>=0.1.1 in d:\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (0.1.2)
# Requirement already satisfied: debugpy>=1.6.5 in d:\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (1.6.7)
# Requirement already satisfied: jupyter-client>=6.1.12 in d:\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (8.6.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in d:\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (5.5.0)
# Requirement already satisfied: psutil in d:\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (5.9.0)
# Requirement already satisfied: pyzmq>=24 in d:\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (25.1.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in d:\anaconda3\lib\site-packages (from jedi>=0.16->ipython<9->ipympl->vaex-jupyter<0.9,>=0.8.2->vaex) (0.8.3)
# Requirement already satisfied: fastjsonschema in d:\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in d:\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (4.19.2)
# Requirement already satisfied: wcwidth in d:\anaconda3\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython<9->ipympl->vaex-jupyter<0.9,>=0.8.2->vaex) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in d:\anaconda3\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (7.0.8)
# Requirement already satisfied: executing in d:\anaconda3\lib\site-packages (from stack-data->ipython<9->ipympl->vaex-jupyter<0.9,>=0.8.2->vaex) (0.8.3)
# Requirement already satisfied: asttokens in d:\anaconda3\lib\site-packages (from stack-data->ipython<9->ipympl->vaex-jupyter<0.9,>=0.8.2->vaex) (2.0.5)
# Requirement already satisfied: pure-eval in d:\anaconda3\lib\site-packages (from stack-data->ipython<9->ipympl->vaex-jupyter<0.9,>=0.8.2->vaex) (0.2.2)
# Requirement already satisfied: attrs>=22.2.0 in d:\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in d:\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in d:\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in d:\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (0.10.6)
# Requirement already satisfied: platformdirs>=2.5 in d:\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (3.10.0)
# Requirement already satisfied: pywin32>=300 in d:\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (305.1)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in d:\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (2.10.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.22.1 in d:\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (2.25.1)
# Requirement already satisfied: jupyterlab<4.1,>=4.0.2 in d:\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (4.0.11)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in d:\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (0.2.3)
# Requirement already satisfied: argon2-cffi in d:\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (21.3.0)
# Requirement already satisfied: jupyter-events>=0.6.0 in d:\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (0.8.0)
# Requirement already satisfied: jupyter-server-terminals in d:\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (0.4.4)
# Requirement already satisfied: nbconvert>=6.4.4 in d:\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (7.10.0)
# Requirement already satisfied: overrides in d:\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (7.4.0)
# Requirement already satisfied: prometheus-client in d:\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (0.14.1)
# Requirement already satisfied: pywinpty in d:\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (2.0.10)
# Requirement already satisfied: send2trash>=1.8.2 in d:\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in d:\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (0.17.1)
# Requirement already satisfied: websocket-client in d:\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (0.58.0)
# Requirement already satisfied: async-lru>=1.0.0 in d:\anaconda3\lib\site-packages (from jupyterlab<4.1,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (2.0.4)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in d:\anaconda3\lib\site-packages (from jupyterlab<4.1,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (2.2.0)
# Requirement already satisfied: babel>=2.10 in d:\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (2.11.0)
# Requirement already satisfied: json5>=0.9.0 in d:\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (0.9.6)
# Requirement already satisfied: python-json-logger>=2.0.4 in d:\anaconda3\lib\site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (2.0.7)
# Requirement already satisfied: rfc3339-validator in d:\anaconda3\lib\site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in d:\anaconda3\lib\site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (0.1.1)
# Requirement already satisfied: beautifulsoup4 in d:\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (4.12.2)
# Requirement already satisfied: bleach!=5.0.0 in d:\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (4.1.0)
# Requirement already satisfied: defusedxml in d:\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in d:\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (0.1.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in d:\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (2.0.4)
# Requirement already satisfied: nbclient>=0.5.0 in d:\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (0.8.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in d:\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (1.5.0)
# Requirement already satisfied: tinycss2 in d:\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (1.2.1)
# Requirement already satisfied: argon2-cffi-bindings in d:\anaconda3\lib\site-packages (from argon2-cffi->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (21.2.0)
# Requirement already satisfied: webencodings in d:\anaconda3\lib\site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (0.5.1)
# Collecting fqdn (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex)
#   Using cached fqdn-1.5.1-py3-none-any.whl.metadata (1.4 kB)
# Collecting isoduration (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex)
#   Using cached isoduration-20.11.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: jsonpointer>1.13 in d:\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (2.1)
# Collecting uri-template (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex)
#   Using cached uri_template-1.3.0-py3-none-any.whl.metadata (8.8 kB)
# Collecting webcolors>=1.11 (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex)
#   Using cached webcolors-1.13-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: cffi>=1.0.1 in d:\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in d:\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (2.5)
# Requirement already satisfied: pycparser in d:\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (2.21)
# Requirement already satisfied: arrow>=0.15.0 in d:\anaconda3\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (1.2.3)
# Using cached vaex-4.17.0-py3-none-any.whl (4.8 kB)
# Using cached vaex_astro-0.9.3-py3-none-any.whl (20 kB)
# Using cached vaex_hdf5-0.14.1-py3-none-any.whl (16 kB)
# Using cached vaex_jupyter-0.8.2-py3-none-any.whl (43 kB)
# Using cached vaex_ml-0.18.3-py3-none-any.whl (58 kB)
# Using cached vaex_server-0.9.0-py3-none-any.whl (23 kB)
# Using cached vaex_viz-0.5.4-py3-none-any.whl (19 kB)
# Using cached bqplot-0.12.43-py2.py3-none-any.whl (1.2 MB)
# Using cached ipyvolume-0.6.3-py3-none-any.whl (1.6 MB)
# Using cached ipyvuetify-1.9.4-py2.py3-none-any.whl (6.1 MB)
# Using cached blake3-0.4.1-cp311-none-win_amd64.whl (210 kB)
# Using cached fastapi-0.110.2-py3-none-any.whl (91 kB)
# Using cached ipyleaflet-0.19.0-py3-none-any.whl (30 kB)
# Using cached ipympl-0.9.4-py3-none-any.whl (516 kB)
# Using cached progressbar2-4.4.2-py3-none-any.whl (56 kB)
# Downloading branca-0.7.2-py3-none-any.whl (25 kB)
# Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# Using cached httptools-0.6.1-cp311-cp311-win_amd64.whl (55 kB)
# Using cached ipyvue-1.11.0-py2.py3-none-any.whl (2.7 MB)
# Using cached jupyter_leaflet-0.19.0-py3-none-any.whl (1.1 MB)
# Using cached python_utils-3.8.2-py2.py3-none-any.whl (27 kB)
# Using cached pythreejs-2.4.2-py3-none-any.whl (3.4 MB)
# Using cached starlette-0.37.2-py3-none-any.whl (71 kB)
# Using cached traittypes-0.2.1-py2.py3-none-any.whl (8.6 kB)
# Using cached watchfiles-0.21.0-cp311-none-win_amd64.whl (280 kB)
# Using cached ipywebrtc-0.6.0-py2.py3-none-any.whl (260 kB)
# Using cached uvicorn-0.29.0-py3-none-any.whl (60 kB)
# Using cached ipydatawidgets-4.3.5-py2.py3-none-any.whl (271 kB)
# Using cached webcolors-1.13-py3-none-any.whl (14 kB)
# Using cached fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Using cached isoduration-20.11.0-py3-none-any.whl (11 kB)
# Using cached uri_template-1.3.0-py3-none-any.whl (11 kB)
# Building wheels for collected packages: vaex-core
#   Building wheel for vaex-core (pyproject.toml): started
#   Building wheel for vaex-core (pyproject.toml): finished with status 'error'
# Failed to build vaex-core
#   error: subprocess-exited-with-error
#
#   Building wheel for vaex-core (pyproject.toml) did not run successfully.
#   exit code: 1
#
#   [191 lines of output]
#   <string>:4: DeprecationWarning: the imp module is deprecated in favour of importlib and slated for removal in Python 3.12; see the module's documentation for alternative uses
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-cpython-311
#   creating build\lib.win-amd64-cpython-311\vaex
#   copying vaex\agg.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\array_types.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\asyncio.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\benchmark.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\cache.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\column.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\config.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\convert.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\cpu.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\csv.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\dataframe.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\dataframe_protocol.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\dataset.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\dataset_misc.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\dataset_mmap.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\dataset_utils.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\datatype.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\datatype_test.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\delayed.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\docstrings.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\encoding.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\events.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\execution.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\export.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\expression.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\expresso.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\formatting.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\functions.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\geo.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\grids.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\groupby.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\hash.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\image.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\itertools.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\join.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\json.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\kld.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\legacy.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\logging.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\memory.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\meta.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\metal.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\minisettings.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\misc_cmdline.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\multiprocessing.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\multithreading.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\parallelize.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\progress.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\promise.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\registry.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\rolling.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\samp.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\schema.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\scopes.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\selections.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\serialize.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\settings.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\shift.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\stat.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\strings.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\struct.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\tasks.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\utils.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\version.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\_version.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\__init__.py -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\__main__.py -> build\lib.win-amd64-cpython-311\vaex
#   creating build\lib.win-amd64-cpython-311\vaex\arrow
#   copying vaex\arrow\convert.py -> build\lib.win-amd64-cpython-311\vaex\arrow
#   copying vaex\arrow\dataset.py -> build\lib.win-amd64-cpython-311\vaex\arrow
#   copying vaex\arrow\numpy_dispatch.py -> build\lib.win-amd64-cpython-311\vaex\arrow
#   copying vaex\arrow\opener.py -> build\lib.win-amd64-cpython-311\vaex\arrow
#   copying vaex\arrow\utils.py -> build\lib.win-amd64-cpython-311\vaex\arrow
#   copying vaex\arrow\utils_test.py -> build\lib.win-amd64-cpython-311\vaex\arrow
#   copying vaex\arrow\_version.py -> build\lib.win-amd64-cpython-311\vaex\arrow
#   creating build\lib.win-amd64-cpython-311\vaex\core
#   copying vaex\core\_version.py -> build\lib.win-amd64-cpython-311\vaex\core
#   copying vaex\core\__init__.py -> build\lib.win-amd64-cpython-311\vaex\core
#   creating build\lib.win-amd64-cpython-311\vaex\file
#   copying vaex\file\asyncio.py -> build\lib.win-amd64-cpython-311\vaex\file
#   copying vaex\file\cache.py -> build\lib.win-amd64-cpython-311\vaex\file
#   copying vaex\file\column.py -> build\lib.win-amd64-cpython-311\vaex\file
#   copying vaex\file\gcs.py -> build\lib.win-amd64-cpython-311\vaex\file
#   copying vaex\file\s3.py -> build\lib.win-amd64-cpython-311\vaex\file
#   copying vaex\file\s3arrow.py -> build\lib.win-amd64-cpython-311\vaex\file
#   copying vaex\file\s3fs.py -> build\lib.win-amd64-cpython-311\vaex\file
#   copying vaex\file\s3_test.py -> build\lib.win-amd64-cpython-311\vaex\file
#   copying vaex\file\__init__.py -> build\lib.win-amd64-cpython-311\vaex\file
#   creating build\lib.win-amd64-cpython-311\vaex\test
#   copying vaex\test\all.py -> build\lib.win-amd64-cpython-311\vaex\test
#   copying vaex\test\cmodule.py -> build\lib.win-amd64-cpython-311\vaex\test
#   copying vaex\test\dataset.py -> build\lib.win-amd64-cpython-311\vaex\test
#   copying vaex\test\expresso.py -> build\lib.win-amd64-cpython-311\vaex\test
#   copying vaex\test\misc.py -> build\lib.win-amd64-cpython-311\vaex\test
#   copying vaex\test\plot.py -> build\lib.win-amd64-cpython-311\vaex\test
#   copying vaex\test\ui.py -> build\lib.win-amd64-cpython-311\vaex\test
#   copying vaex\test\__init__.py -> build\lib.win-amd64-cpython-311\vaex\test
#   copying vaex\test\__main__.py -> build\lib.win-amd64-cpython-311\vaex\test
#   creating build\lib.win-amd64-cpython-311\vaex\ext
#   copying vaex\ext\bokeh.py -> build\lib.win-amd64-cpython-311\vaex\ext
#   copying vaex\ext\common.py -> build\lib.win-amd64-cpython-311\vaex\ext
#   copying vaex\ext\ipyvolume.py -> build\lib.win-amd64-cpython-311\vaex\ext
#   copying vaex\ext\jprops.py -> build\lib.win-amd64-cpython-311\vaex\ext
#   copying vaex\ext\readcol.py -> build\lib.win-amd64-cpython-311\vaex\ext
#   copying vaex\ext\__init__.py -> build\lib.win-amd64-cpython-311\vaex\ext
#   creating build\lib.win-amd64-cpython-311\vaex\misc
#   copying vaex\misc\expressions.py -> build\lib.win-amd64-cpython-311\vaex\misc
#   copying vaex\misc\ordereddict.py -> build\lib.win-amd64-cpython-311\vaex\misc
#   copying vaex\misc\pandawrap.py -> build\lib.win-amd64-cpython-311\vaex\misc
#   copying vaex\misc\parallelize.py -> build\lib.win-amd64-cpython-311\vaex\misc
#   copying vaex\misc\progressbar.py -> build\lib.win-amd64-cpython-311\vaex\misc
#   copying vaex\misc\samp.py -> build\lib.win-amd64-cpython-311\vaex\misc
#   copying vaex\misc\__init__.py -> build\lib.win-amd64-cpython-311\vaex\misc
#   creating build\lib.win-amd64-cpython-311\vaex\datasets
#   copying vaex\datasets\__init__.py -> build\lib.win-amd64-cpython-311\vaex\datasets
#   running egg_info
#   writing vaex_core.egg-info\PKG-INFO
#   writing dependency_links to vaex_core.egg-info\dependency_links.txt
#   writing entry points to vaex_core.egg-info\entry_points.txt
#   writing requirements to vaex_core.egg-info\requires.txt
#   writing top-level names to vaex_core.egg-info\top_level.txt
#   reading manifest file 'vaex_core.egg-info\SOURCES.txt'
#   reading manifest template 'MANIFEST.in'
#   warning: no files found matching '*.c' under directory 'vendor'
#   warning: no files found matching '*.h' under directory 'src'
#   warning: no files found matching '*.c' under directory 'src'
#   adding license file 'LICENSE.txt'
#   writing manifest file 'vaex_core.egg-info\SOURCES.txt'
#   C:\Users\Антоша\AppData\Local\Temp\pip-build-env-ygoulwt3\overlay\Lib\site-packages\setuptools\command\build_py.py:207: _Warning: Package 'vaex.test.files' is absent from the `packages` configuration.
#   !!
#
#           ********************************************************************************
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'vaex.test.files' as an importable package[^1],
#           but it is absent from setuptools' `packages` configuration.
#
#           This leads to an ambiguous overall configuration. If you want to distribute this
#           package, please make sure that 'vaex.test.files' is explicitly added
#           to the `packages` configuration field.
#
#           Alternatively, you can also rely on setuptools' discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" on setuptools documentation page:
#
#           - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#           If you don't want 'vaex.test.files' to be distributed and are
#           already explicitly excluding 'vaex.test.files' via
#           `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#           you can try to use `exclude_package_data`, or `include-package-data=False` in
#           combination with a more fine grained `package-data` configuration.
#
#           You can read more about "package data files" on setuptools documentation page:
#
#           - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#           [^1]: For Python, any directory (with suitable naming) can be imported,
#                 even if it does not contain any `.py` files.
#                 On the other hand, currently there is no concept of package data
#                 directory, all directories are treated like packages.
#           ********************************************************************************
#
#   !!
#     check.warn(importable)
#   copying vaex\pcre.dll -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\pcrecpp.dll -> build\lib.win-amd64-cpython-311\vaex
#   copying vaex\vcruntime140_1.dll -> build\lib.win-amd64-cpython-311\vaex
#   creating build\lib.win-amd64-cpython-311\vaex\test\files
#   copying vaex\test\files\gaia-small-colfits-basic.fits -> build\lib.win-amd64-cpython-311\vaex\test\files
#   copying vaex\test\files\gaia-small-colfits-plus.fits -> build\lib.win-amd64-cpython-311\vaex\test\files
#   copying vaex\test\files\gaia-small-fits-basic.fits -> build\lib.win-amd64-cpython-311\vaex\test\files
#   copying vaex\test\files\gaia-small-fits-plus.fits -> build\lib.win-amd64-cpython-311\vaex\test\files
#   copying vaex\test\files\gaia-small-votable.vot -> build\lib.win-amd64-cpython-311\vaex\test\files
#   copying vaex\test\files\default_amuse_plummer.hdf5 -> build\lib.win-amd64-cpython-311\vaex\test\files
#   copying vaex\datasets\iris.hdf5 -> build\lib.win-amd64-cpython-311\vaex\datasets
#   copying vaex\datasets\titanic.hdf5 -> build\lib.win-amd64-cpython-311\vaex\datasets
#   running build_ext
#   building 'vaex.vaexfast' extension
#   error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for vaex-core
# ERROR: Could not build wheels for vaex-core, which is required to install pyproject.toml-based projects

# %%
import pickle
index_list, feature_list, data_matrix = pickle.load(open('water_dataset', 'rb'))

# %% [markdown]
# * `index_list` — список id рек, которые были отобраны для задания
# * `feature_list` — список признаков (они имеют вид `год ПРОБЕЛ показатель`)
# * `data_matrix` — собственно данные (строки соответствуют рекам из `index_list`, а столбцы — признакам из `feature_list`)

# %% [markdown]
# Давайте попробуем сделать PCA, визуализровать данные в пространстве первых двух компонент и проинтерпретировать первые главные компоненты.

# %%
X = data_matrix.copy()
X.shape
# Out:
# (500, 532)

# %%
from sklearn.decomposition import PCA

model_pca = PCA(10) # оставим 10 компонент
X_pca = model_pca.fit_transform(X)

plt.scatter(X_pca[:,0], X_pca[:,1]);

# %% [markdown]
# Прямое применение PCA  к данным не дало хорошего результата:
#
# - Вспомним, что PCA пытается выделять главные компоненты, максимизируя дисперсию. Дисперсия чувствительна к выбросам, значит, и метод главных компонент чувствителен к ним
# - Судя по всему, у данных разные единицы измерения. Значит, разброс несопоставим. PCA запутался

# %%
plt.hist(X.max(axis=0), bins=30,log=True);

# %% [markdown]
# Срежем выбросы по 99 % квантилю, а затем стандартизируем данные.

# %%
replace = np.percentile(X, 99, axis=0)
for i in range(X.shape[1]):
    X[:,i][X[:,i] > replace[i]] = replace[i]

# %%
plt.hist(X.max(axis=0), bins=30,log=True);

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scal = scaler.fit_transform(X)

# %%
model_pca = PCA(10)
X_pca = model_pca.fit_transform(X_scal)

plt.scatter(X_pca[:,0], X_pca[:,1]);

# %% [markdown]
# Визуализация стала лучше. Чтобы понять физический смысл первых признаков, посмотрим, из каких колонок они формируются.

# %%
sorted(list(zip(feature_list, np.abs(model_pca.components_[0]))), key = lambda w : w[1], reverse=True)[:20]
# Out:
# [('1992 Nitrate', 0.07205514167463652),
#  ('1994 Nitrate', 0.07145770940394157),
#  ('1993 Nitrate', 0.06953996244973612),
#  ('1990 pH', 0.06899899935368567),
#  ('1994 Nitrite', 0.06892630086390454),
#  ('1989 pH', 0.06879277214220082),
#  ('1995 Nitrate', 0.06821782583892054),
#  ('1997 Nitrate', 0.0679660058189696),
#  ('1997 Dissolved oxygen', 0.06794410190616794),
#  ('1992 Nitrite', 0.06791502888673775),
#  ('1991 pH', 0.0677594568278405),
#  ('1998 Total phosphorus', 0.0676151004162904),
#  ('1992 pH', 0.06752486404460212),
#  ('1993 Nitrite', 0.06748580450611903),
#  ('2002 Nitrate', 0.06726143675036035),
#  ('1999 Nitrate', 0.06705702189135082),
#  ('2002 Total phosphorus', 0.06705015770807103),
#  ('1996 Dissolved oxygen', 0.06691960685686547),
#  ('1995 Nitrite', 0.06670574760873399),
#  ('1998 Dissolved oxygen', 0.06654171398359399)]

# %%
sorted(list(zip(feature_list, np.abs(model_pca.components_[1]))), key = lambda w : w[1], reverse=True)[:20]
# Out:
# [('2006 Total organic carbon (TOC)', 0.10041321449682167),
#  ('2005 Total organic carbon (TOC)', 0.09772568450458813),
#  ('2005 CODMn', 0.09077344156953358),
#  ('2004 CODMn', 0.08934944037390745),
#  ('1999 Total nitrogen', 0.08912593532340397),
#  ('1996 Total organic nitrogen', 0.08896511702814074),
#  ('1998 Total nitrogen', 0.08890103684332637),
#  ('1997 Total nitrogen', 0.08815045390348386),
#  ('2000 Total nitrogen', 0.08793498941700147),
#  ('1996 Total nitrogen', 0.08785326728275297),
#  ('1986 Total organic nitrogen', 0.08772444881772631),
#  ('2009 CODMn', 0.08768984047796005),
#  ('1995 Total nitrogen', 0.08745538919212195),
#  ('2002 CODMn', 0.0872759668276825),
#  ('2001 CODMn', 0.08695775051660326),
#  ('1985 Total organic nitrogen', 0.08689670393447153),
#  ('2009 Total organic carbon (TOC)', 0.08656463369093634),
#  ('1995 Total organic nitrogen', 0.0863395971824548),
#  ('2006 CODMn', 0.08616992064355704),
#  ('1994 Total nitrogen', 0.08569178674510647)]

# %%
sorted(list(zip(feature_list, np.abs(model_pca.components_[3]))), key = lambda w : w[1], reverse=True)[:20]
# Out:
# [('1989 Total inorganic nitrogen', 0.13527153141917797),
#  ('1991 Total inorganic nitrogen', 0.1339142131067911),
#  ('1990 Total inorganic nitrogen', 0.13350701356669095),
#  ('1987 Total inorganic nitrogen', 0.13308265092572055),
#  ('1988 Total inorganic nitrogen', 0.13242619223171231),
#  ('1989 Total oxidised nitrogen', 0.1303788572215108),
#  ('1987 Total oxidised nitrogen', 0.12953020611819926),
#  ('1988 Total oxidised nitrogen', 0.12840159026903264),
#  ('1990 Total oxidised nitrogen', 0.12680036717820312),
#  ('1991 Total oxidised nitrogen', 0.1243874032178744),
#  ('1992 Total oxidised nitrogen', 0.12270180024633467),
#  ('1993 Total oxidised nitrogen', 0.11842012469743428),
#  ('1994 Total oxidised nitrogen', 0.11596298321755794),
#  ('1995 Total oxidised nitrogen', 0.11552744969636232),
#  ('1996 Total oxidised nitrogen', 0.11252133360049944),
#  ('1998 Total oxidised nitrogen', 0.10438609481564982),
#  ('1987 CODMn', 0.10161880654931962),
#  ('1989 CODMn', 0.10107353314398644),
#  ('1999 Total oxidised nitrogen', 0.10059930497384952),
#  ('1987 Total ammonium', 0.10042294841587199)]

# %% [markdown]
# ## 2.4. PCA с ядрами
#
# Так как PCA фактически работает не с исходными признаками, а с матрицей их ковариаций, можно использовать для ее вычисления вместо скалярного произведения $\langle x_i, x_j \rangle$ произвольное ядро $K(x_i, x_j)$. Это будет соответствовать переходу в другое пространство. Единственная проблема &mdash; непонятно, как подбирать ядро.
#
# Ниже приведены примеры объектов в исходном пространстве (похожие группы обозначены одним цветом для наглядности) и результат их трансформации в новые пространства (для разных ядер). Если результаты получаются линейно разделимыми, значит мы выбрали подходящее ядро.

# %%
from sklearn.decomposition import KernelPCA

def KPCA_show(X, y):
    reds = y == 0
    blues = y == 1
    
    plt.figure(figsize=(8, 8))
    rows, cols = 2, 2
    plt.subplot(rows, cols, 1)
    plt.scatter(X[reds, 0], X[reds, 1], alpha=0.5, c='r')
    plt.scatter(X[blues, 0], X[blues, 1], alpha=0.5, c='b')
    ax = plt.gca()
    ax.set_aspect('equal', adjustable='box')
    
    kernels_params = [
        dict(kernel='rbf', gamma=10),
        dict(kernel='poly', gamma=10),
        dict(kernel='cosine', gamma=10),
    ]
    
    for i, p in enumerate(kernels_params):
        dec = KernelPCA(**p)
        X_transformed = dec.fit_transform(X)
        
        plt.subplot(rows, cols, i + 2)
        plt.scatter(X_transformed[reds, 0], X_transformed[reds, 1], alpha=0.5, c='r')
        plt.scatter(X_transformed[blues, 0], X_transformed[blues, 1], alpha=0.5, c='b')
        ax = plt.gca()
        ax.set_aspect('equal', adjustable='box')
        
np.random.seed(54242)
KPCA_show(*make_circles(n_samples=1000, factor=0.2, noise=0.1))

# %%
np.random.seed(54242)
KPCA_show(*make_moons(n_samples=1000, noise=0.1))

# %% [markdown]
# # 3. TSNE (t-distributed Stohastic Neighbor Embedding)
#
# Джефри Хинтон не просто сказал слова из эпиграфа к этой тетрадке, но и вместе со своим аспирантом в 2008 г. придумал [новый метод визуализации данных.](https://www.jmlr.org/papers/volume9/vandermaaten08a/vandermaaten08a.pdf) Основная идея метода состоит в поиске отображения из многомерного признакового пространства на плоскость (или в многомерное пространство меньшей размерности, но почти всегда выбирают 2D), чтобы точки, которые были далеко друг от друга, на плоскости тоже оказались удаленными, а близкие точки также отобразились на близкие. То есть neighbor embedding – это своего рода поиск нового представления данных, при котором сохраняется отношение соседства.
#
# Попробуем взять данные о рукописных цифрах и визуализируем их с помощью PCA.

# %%
from sklearn.datasets import load_digits
digits = load_digits()

X = digits.data
y = digits.target

plt.figure(figsize=(16, 6))
for i in range(10):
    plt.subplot(2, 5, i + 1)
    plt.imshow(X[i,:].reshape([8,8]), cmap='gray');

# %%
X.shape
# Out:
# (1797, 64)

# %% [markdown]
# Получается, размерность признакового пространства здесь 64. Но давайте снизим размерность всего до 2 и увидим, что даже на глаз рукописные цифры неплохо разделяются на кластеры.

# %%
model_pca = PCA(n_components=2)
X_reduced = model_pca.fit_transform(X)

plt.figure(figsize=(12,10))
plt.scatter(X_reduced[:, 0], X_reduced[:, 1], c=y, 
            edgecolor='none', alpha=0.7, s=40,
            cmap=plt.cm.get_cmap('nipy_spectral', 10))
plt.colorbar()
plt.title('MNIST. PCA projection');

# %% [markdown]
# Попробуем сделать то же самое с помощью t-SNE. Картинка получится лучше, так как у PCA есть существенное ограничение: он находит только линейные комбинации исходных признаков, если не добавить какое-нибудь ядро.

# %%
from sklearn.manifold import TSNE

tsne = TSNE(n_jobs=4, perplexity=30, random_state=42)
X_tsne = tsne.fit_transform(X)

plt.figure(figsize=(12,10))
plt.scatter(X_tsne[:, 0], X_tsne[:, 1], c=y, 
            edgecolor='none', alpha=0.7, s=40,
            cmap=plt.cm.get_cmap('nipy_spectral', 10))

plt.colorbar()
plt.title('MNIST. t-SNE projection');
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,

# %% [markdown]
# У метода есть параметр `Perplexity`, который отвечает за то, насколько сильно точки могут разлететься друг от друга.

# %%
tsne = TSNE(n_jobs=4, perplexity=2, random_state=42)
X_tsne = tsne.fit_transform(X)

plt.figure(figsize=(12,10))
plt.scatter(X_tsne[:, 0], X_tsne[:, 1], c=y, 
            edgecolor='none', alpha=0.7, s=40,
            cmap=plt.cm.get_cmap('nipy_spectral', 10))

plt.colorbar()
plt.title('MNIST. t-SNE projection');
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,

# %% [markdown]
# Итоговая картинка может сильно поменяться при изменении `random_state`, это усложняет интерпретацию. В целом по таким картинкам не стоит делать далеко идущих выводов – не стоит гадать по кофейной гуще.

# %% [markdown]
# В 2018 г. был предложен еще один алгоритм нелинейного снижения размерности — [UMAP.](https://umap-learn.readthedocs.io/en/latest/) Он похож на TSNE, но работает быстрее и более эффективен.

# %% [markdown]
# - [Статья](https://habr.com/ru/company/io/blog/265089/) «Как подобрать платье с помощью метода главных компонент»
# - [Q&A Разбор PCA с интуицией и примерами](https://stats.stackexchange.com/questions/2691/making-sense-of-principal-component-analysis-eigenvectors-eigenvalues)
# - [Distillpub о TSNE](https://distill.pub/2016/misread-tsne/)
# - [Подробнее про UMAP](https://pair-code.github.io/understanding-umap/)

# %% [markdown]
# Подведем итоги:
# - Отбор признаков не всегда способен снизить размерность нашего пространства, иногда лучше делать это другими способами
# - Для линейного снижения размерности используют метод главных компонент. Для его работы желательно нормализовать данные, чтобы масштаб по всем признакам был примерно одинаковый. PCA не учитывает значение целевой переменной
# - Для нелинейного снижения размерности обычно используют t-SNE и UMAP. Оба работают достаточно быстро и дают красивые картинки
# - Однако эти нелинейные методы нельзя использовать, чтобы снизить размерность для новой точки. В этом случае лучше подойдут автокодировщики на основе нейронных сетей и другие методы построения представлений данных
